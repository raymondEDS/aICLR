# %%
import openreview
import pandas as pd
import datetime as date
import tqdm
import json
import ast
import itertools
import matplotlib.pyplot as plt
import requests, json
client = openreview.Client(baseurl='https://api.openreview.net')

# %%
df_author_profiles = pd.read_csv('data/authors/df_author_profiles.csv')
df_submissions = pd.read_csv('data/submissions/df_submissions.csv',index_col=0)

# %%
def lambda_get_first_last_author(row):
    first_author_name = str()
    first_author_id = str()
    last_author_name = str()
    last_author_id = str()
    
    try:
        lst_names = ast.literal_eval(row['authors'])
        lst_ids = ast.literal_eval(row['authorids'])
        first_author_name = lst_names[0]
        last_author_name = lst_names[-1]
        first_author_id = lst_ids[0]
        last_author_id = lst_ids[-1]
    except:
        first_author_name = 'error'
        last_author_name = 'error'
        first_author_id = 'error'
        last_author_id = 'error'
        
    return first_author_name, last_author_name, first_author_id, last_author_id

# %%
df_submissions[['first_author_name','last_author_name','first_author_id','last_author_id']] = df_submissions.apply(lambda x: lambda_get_first_last_author(x), axis = 1 , result_type='expand')

# %%
df_submissions
# Out:
#               id    original  number         cdate  mdate         tcdate  \
# 0      S1VaB4cex         NaN     214           NaN    NaN  1478276540541
# 1      H1W1UN9gg         NaN     215           NaN    NaN  1478276569300
# 2      r1GKzP5xx         NaN     370           NaN    NaN  1478287994558
# 3      S1J0E-71l         NaN       2           NaN    NaN  1476756679535
# 4      SJGCiw5gl         NaN     427           NaN    NaN  1478290378652
# ...          ...         ...     ...           ...    ...            ...
# 1414  BkE8NjCqYm  Hyxdt-7YYm       6  1.538088e+12    NaN  1538087726374
# 1415  BJfIVjAcKm  SJl8QZNFKm       4  1.538088e+12    NaN  1538087725988
# 1416  Hkl84iCcFm  HygqaYAcFm       3  1.538088e+12    NaN  1538087725796
# 1417  S1gUVjCqKm  HyenhvCqKX       2  1.538088e+12    NaN  1538087725593
# 1418  H1xSNiRcF7  HkltNFR5Ym       1  1.538088e+12    NaN  1538087725357
#
#              tmdate  ddate       forum  referent  ...  \
# 0     1658433096672    NaN   S1VaB4cex       NaN  ...
# 1     1658433096913    NaN   H1W1UN9gg       NaN  ...
# 2     1658434077890    NaN   r1GKzP5xx       NaN  ...
# 3     1658433097410    NaN   S1J0E-71l       NaN  ...
# 4     1658433097637    NaN   SJGCiw5gl       NaN  ...
# ...             ...    ...         ...       ...  ...
# 1414  1545355398839    NaN  BkE8NjCqYm       NaN  ...
# 1415  1644492706715    NaN  BJfIVjAcKm       NaN  ...
# 1416  1545355412821    NaN  Hkl84iCcFm       NaN  ...
# 1417  1545355420919    NaN  S1gUVjCqKm       NaN  ...
# 1418  1550884085382    NaN  H1xSNiRcF7       NaN  ...
#
#                       venueid  \
# 0     ICLR.cc/2017/conference
# 1     ICLR.cc/2017/conference
# 2     ICLR.cc/2017/conference
# 3     ICLR.cc/2017/conference
# 4     ICLR.cc/2017/conference
# ...                       ...
# 1414                      NaN
# 1415                      NaN
# 1416                      NaN
# 1417                      NaN
# 1418                      NaN
#
#                                                 _bibtex  \
# 0     @inproceedings{\nlarsson2017fractalnet,\ntitle...
# 1     @inproceedings{\nschoenholz2017deep,\ntitle={D...
# 2     @misc{\nlee2017making,\ntitle={Making Stochast...
# 3     @misc{\nrocki2017surprisaldriven,\ntitle={Surp...
# 4     @inproceedings{\nmolchanov2017pruning,\ntitle=...
# ...                                                 ...
# 1414  @misc{\ncohen2019unconstrained,\ntitle={(Uncon...
# 1415  @inproceedings{\nxiao2018training,\ntitle={Tra...
# 1416  @misc{\nlagzi2019residual,\ntitle={{RESIDUAL} ...
# 1417  @misc{\nhan2019unsupervised,\ntitle={Unsupervi...
# 1418  @inproceedings{\nli2018smoothing,\ntitle={Smoo...
#
#                                               paperhash       author_emails  \
# 0     larsson|fractalnet_ultradeep_neural_networks_w...                 NaN
# 1               schoenholz|deep_information_propagation                 NaN
# 2           laurent|recurrent_normalization_propagation                 NaN
# 3      k|surprisaldriven_feedback_in_recurrent_networks  kmrocki@us.ibm.com
# 4     molchanov|pruning_convolutional_neural_network...                 NaN
# ...                                                 ...                 ...
# 1414  cohen|unconstrained_beam_search_is_sensitive_t...                 NaN
# 1415  xiao|training_for_faster_adversarial_robustnes...                 NaN
# 1416  lagzi|residual_networks_classify_inputs_based_...                 NaN
# 1417  han|unsupervised_classification_into_unknown_n...                 NaN
# 1418  li|smoothing_the_geometry_of_probabilistic_box...                 NaN
#
#                                                    code data  \
# 0                                                   NaN  NaN
# 1                                                   NaN  NaN
# 2                                                   NaN  NaN
# 3                                                   NaN  NaN
# 4                                                   NaN  NaN
# ...                                                 ...  ...
# 1414                                                NaN  NaN
# 1415  [![github](/images/github_icon.svg) MadryLab/r...  NaN
# 1416                                                NaN  NaN
# 1417                                                NaN  NaN
# 1418                                                NaN  NaN
#
#          first_author_name       last_author_name  \
# 0           Gustav Larsson  Gregory Shakhnarovich
# 1     Samuel S. Schoenholz  Jascha Sohl-Dickstein
# 2            César Laurent         Pascal Vincent
# 3                    error                  error
# 4          Pavlo Molchanov              Jan Kautz
# ...                    ...                    ...
# 1414           Eldan Cohen    J. Christopher Beck
# 1415           Kai Y. Xiao       Aleksander Madry
# 1416       Fereshteh Lagzi        Fereshteh Lagzi
# 1417          Sungyeob Han            Jungwoo Lee
# 1418              Xiang Li        Andrew McCallum
#
#                        first_author_id                    last_author_id
# 0              larsson@cs.uchicago.edu                     greg@ttic.edu
# 1                    schsam@google.com               jaschasd@google.com
# 2           cesar.laurent@umontreal.ca       pascal.vincent@umontreal.ca
# 3                                error                             error
# 4                pmolchanov@nvidia.com                 jkautz@nvidia.com
# ...                                ...                               ...
# 1414            ecohen@mie.utoronto.ca               jcb@mie.utoronto.ca
# 1415                      kaix@mit.edu                     madry@mit.edu
# 1416  lagzi@informatik.uni-freiburg.de  lagzi@informatik.uni-freiburg.de
# 1417               syhan@cml.snu.ac.kr                 junglee@snu.ac.kr
# 1418               xiangl@cs.umass.edu             mccallum@cs.umass.edu
#
# [2820 rows x 36 columns]

# %%
search = 'https://api.openalex.org/authors?filter=display_name.search:'
name = 'Liu Yang'

test = search + name

# %%
def lambda_get_OpenAlex_request(row):
    search = 'https://api.openalex.org/authors?filter=display_name.search:'
    first_author_name = row['first_author_name']
    last_author_name = row['last_author_name']
    
    search_first_author = search + first_author_name
    return json.loads(requests.get(search_first_author).text)['results']

# %%
tqdm.tqdm.pandas()


df_submissions.progress_apply(lambda x : lambda_get_OpenAlex_request(x), axis = 1)
# Out:
# 100%|███████████████████████████████████████| 2820/2820 [23:50<00:00,  1.97it/s]
# 0       [{'id': 'https://openalex.org/A2338325017', 'o...
# 1       [{'id': 'https://openalex.org/A2833214316', 'o...
# 2       [{'id': 'https://openalex.org/A2250018335', 'o...
# 3       [{'id': 'https://openalex.org/A401312156', 'or...
# 4       [{'id': 'https://openalex.org/A2777799004', 'o...
#                               ...
# 1414    [{'id': 'https://openalex.org/A2604423490', 'o...
# 1415                                                   []
# 1416    [{'id': 'https://openalex.org/A1974555589', 'o...
# 1417    [{'id': 'https://openalex.org/A2613955392', 'o...
# 1418    [{'id': 'https://openalex.org/A2805077430', 'o...
# Length: 2820, dtype: object

# %%
df_submissions
# Out:
#               id    original  number         cdate  mdate         tcdate  \
# 0      S1VaB4cex         NaN     214           NaN    NaN  1478276540541
# 1      H1W1UN9gg         NaN     215           NaN    NaN  1478276569300
# 2      r1GKzP5xx         NaN     370           NaN    NaN  1478287994558
# 3      S1J0E-71l         NaN       2           NaN    NaN  1476756679535
# 4      SJGCiw5gl         NaN     427           NaN    NaN  1478290378652
# ...          ...         ...     ...           ...    ...            ...
# 1414  BkE8NjCqYm  Hyxdt-7YYm       6  1.538088e+12    NaN  1538087726374
# 1415  BJfIVjAcKm  SJl8QZNFKm       4  1.538088e+12    NaN  1538087725988
# 1416  Hkl84iCcFm  HygqaYAcFm       3  1.538088e+12    NaN  1538087725796
# 1417  S1gUVjCqKm  HyenhvCqKX       2  1.538088e+12    NaN  1538087725593
# 1418  H1xSNiRcF7  HkltNFR5Ym       1  1.538088e+12    NaN  1538087725357
#
#              tmdate  ddate       forum  referent  ...  \
# 0     1658433096672    NaN   S1VaB4cex       NaN  ...
# 1     1658433096913    NaN   H1W1UN9gg       NaN  ...
# 2     1658434077890    NaN   r1GKzP5xx       NaN  ...
# 3     1658433097410    NaN   S1J0E-71l       NaN  ...
# 4     1658433097637    NaN   SJGCiw5gl       NaN  ...
# ...             ...    ...         ...       ...  ...
# 1414  1545355398839    NaN  BkE8NjCqYm       NaN  ...
# 1415  1644492706715    NaN  BJfIVjAcKm       NaN  ...
# 1416  1545355412821    NaN  Hkl84iCcFm       NaN  ...
# 1417  1545355420919    NaN  S1gUVjCqKm       NaN  ...
# 1418  1550884085382    NaN  H1xSNiRcF7       NaN  ...
#
#                       venueid  \
# 0     ICLR.cc/2017/conference
# 1     ICLR.cc/2017/conference
# 2     ICLR.cc/2017/conference
# 3     ICLR.cc/2017/conference
# 4     ICLR.cc/2017/conference
# ...                       ...
# 1414                      NaN
# 1415                      NaN
# 1416                      NaN
# 1417                      NaN
# 1418                      NaN
#
#                                                 _bibtex  \
# 0     @inproceedings{\nlarsson2017fractalnet,\ntitle...
# 1     @inproceedings{\nschoenholz2017deep,\ntitle={D...
# 2     @misc{\nlee2017making,\ntitle={Making Stochast...
# 3     @misc{\nrocki2017surprisaldriven,\ntitle={Surp...
# 4     @inproceedings{\nmolchanov2017pruning,\ntitle=...
# ...                                                 ...
# 1414  @misc{\ncohen2019unconstrained,\ntitle={(Uncon...
# 1415  @inproceedings{\nxiao2018training,\ntitle={Tra...
# 1416  @misc{\nlagzi2019residual,\ntitle={{RESIDUAL} ...
# 1417  @misc{\nhan2019unsupervised,\ntitle={Unsupervi...
# 1418  @inproceedings{\nli2018smoothing,\ntitle={Smoo...
#
#                                               paperhash       author_emails  \
# 0     larsson|fractalnet_ultradeep_neural_networks_w...                 NaN
# 1               schoenholz|deep_information_propagation                 NaN
# 2           laurent|recurrent_normalization_propagation                 NaN
# 3      k|surprisaldriven_feedback_in_recurrent_networks  kmrocki@us.ibm.com
# 4     molchanov|pruning_convolutional_neural_network...                 NaN
# ...                                                 ...                 ...
# 1414  cohen|unconstrained_beam_search_is_sensitive_t...                 NaN
# 1415  xiao|training_for_faster_adversarial_robustnes...                 NaN
# 1416  lagzi|residual_networks_classify_inputs_based_...                 NaN
# 1417  han|unsupervised_classification_into_unknown_n...                 NaN
# 1418  li|smoothing_the_geometry_of_probabilistic_box...                 NaN
#
#                                                    code data  \
# 0                                                   NaN  NaN
# 1                                                   NaN  NaN
# 2                                                   NaN  NaN
# 3                                                   NaN  NaN
# 4                                                   NaN  NaN
# ...                                                 ...  ...
# 1414                                                NaN  NaN
# 1415  [![github](/images/github_icon.svg) MadryLab/r...  NaN
# 1416                                                NaN  NaN
# 1417                                                NaN  NaN
# 1418                                                NaN  NaN
#
#          first_author_name       last_author_name  \
# 0           Gustav Larsson  Gregory Shakhnarovich
# 1     Samuel S. Schoenholz  Jascha Sohl-Dickstein
# 2            César Laurent         Pascal Vincent
# 3                    error                  error
# 4          Pavlo Molchanov              Jan Kautz
# ...                    ...                    ...
# 1414           Eldan Cohen    J. Christopher Beck
# 1415           Kai Y. Xiao       Aleksander Madry
# 1416       Fereshteh Lagzi        Fereshteh Lagzi
# 1417          Sungyeob Han            Jungwoo Lee
# 1418              Xiang Li        Andrew McCallum
#
#                        first_author_id                    last_author_id
# 0              larsson@cs.uchicago.edu                     greg@ttic.edu
# 1                    schsam@google.com               jaschasd@google.com
# 2           cesar.laurent@umontreal.ca       pascal.vincent@umontreal.ca
# 3                                error                             error
# 4                pmolchanov@nvidia.com                 jkautz@nvidia.com
# ...                                ...                               ...
# 1414            ecohen@mie.utoronto.ca               jcb@mie.utoronto.ca
# 1415                      kaix@mit.edu                     madry@mit.edu
# 1416  lagzi@informatik.uni-freiburg.de  lagzi@informatik.uni-freiburg.de
# 1417               syhan@cml.snu.ac.kr                 junglee@snu.ac.kr
# 1418               xiangl@cs.umass.edu             mccallum@cs.umass.edu
#
# [2820 rows x 36 columns]

# %%
response = requests.get(test)
response
# Out:
# <Response [200]>

# %%
res = json.loads(response.text)

# %%
res['results']
# Out:
# [{'id': 'https://openalex.org/A2776297621',
#   'orcid': 'https://orcid.org/0000-0001-5477-2186',
#   'display_name': 'Yang Liu',
#   'display_name_alternatives': ['刘阳'],
#   'relevance_score': 3901.0784,
#   'works_count': 2764,
#   'cited_by_count': 124390,
#   'ids': {'openalex': 'https://openalex.org/A2776297621',
#    'orcid': 'https://orcid.org/0000-0001-5477-2186',
#    'mag': '2776297621'},
#   'last_known_institution': {'id': 'https://openalex.org/I157773358',
#    'ror': 'https://ror.org/0064kty71',
#    'display_name': 'Sun Yat-sen University',
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 77.9},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 76.3},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 63.7},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 53.2},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 50.5},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 48.4},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 46.1},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 42.6},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 42.4},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 38.8},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 30.2},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 28.9},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 27.1},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 27.0},
#    {'id': 'https://openalex.org/C159985019',
#     'wikidata': 'https://www.wikidata.org/wiki/Q181790',
#     'display_name': 'Composite material',
#     'level': 1,
#     'score': 25.9},
#    {'id': 'https://openalex.org/C171250308',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11468',
#     'display_name': 'Nanotechnology',
#     'level': 1,
#     'score': 25.7},
#    {'id': 'https://openalex.org/C18903297',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#     'display_name': 'Ecology',
#     'level': 1,
#     'score': 25.6},
#    {'id': 'https://openalex.org/C42360764',
#     'wikidata': 'https://www.wikidata.org/wiki/Q83588',
#     'display_name': 'Chemical engineering',
#     'level': 1,
#     'score': 23.0},
#    {'id': 'https://openalex.org/C120665830',
#     'wikidata': 'https://www.wikidata.org/wiki/Q14620',
#     'display_name': 'Optics',
#     'level': 1,
#     'score': 22.2},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 21.3}],
#   'counts_by_year': [{'year': 2022,
#     'works_count': 111,
#     'cited_by_count': 15885},
#    {'year': 2021, 'works_count': 429, 'cited_by_count': 27120},
#    {'year': 2020, 'works_count': 353, 'cited_by_count': 20619},
#    {'year': 2019, 'works_count': 299, 'cited_by_count': 17744},
#    {'year': 2018, 'works_count': 269, 'cited_by_count': 13406},
#    {'year': 2017, 'works_count': 231, 'cited_by_count': 10277},
#    {'year': 2016, 'works_count': 206, 'cited_by_count': 6992},
#    {'year': 2015, 'works_count': 220, 'cited_by_count': 4727},
#    {'year': 2014, 'works_count': 161, 'cited_by_count': 2804},
#    {'year': 2013, 'works_count': 122, 'cited_by_count': 1551},
#    {'year': 2012, 'works_count': 102, 'cited_by_count': 898}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2776297621',
#   'updated_date': '2022-08-07T15:20:44.192769',
#   'created_date': '2018-01-05'},
#  {'id': 'https://openalex.org/A3191665970',
#   'orcid': None,
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 2387.3186,
#   'works_count': 7,
#   'cited_by_count': 5176,
#   'ids': {'openalex': 'https://openalex.org/A3191665970', 'mag': '3191665970'},
#   'last_known_institution': {'id': 'https://openalex.org/I9916479',
#    'ror': 'https://ror.org/00ms48f15',
#    'display_name': 'Air Force Medical University',
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 85.7},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 85.7},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 71.4},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 71.4},
#    {'id': 'https://openalex.org/C190283241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q14599311',
#     'display_name': 'Apoptosis',
#     'level': 2,
#     'score': 71.4},
#    {'id': 'https://openalex.org/C203522944',
#     'wikidata': 'https://www.wikidata.org/wiki/Q288322',
#     'display_name': 'Autophagy',
#     'level': 3,
#     'score': 71.4},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 57.1},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': 57.1},
#    {'id': 'https://openalex.org/C70721500',
#     'wikidata': 'https://www.wikidata.org/wiki/Q177005',
#     'display_name': 'Computational biology',
#     'level': 1,
#     'score': 42.9},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 42.9},
#    {'id': 'https://openalex.org/C95444343',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7141',
#     'display_name': 'Cell biology',
#     'level': 1,
#     'score': 42.9},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 42.9},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 42.9},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C41895202',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8162',
#     'display_name': 'Linguistics',
#     'level': 1,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C191897082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11467',
#     'display_name': 'Metallurgy',
#     'level': 1,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 28.6},
#    {'id': 'https://openalex.org/C527412718',
#     'wikidata': 'https://www.wikidata.org/wiki/Q855395',
#     'display_name': 'Interpretation (philosophy)',
#     'level': 2,
#     'score': 28.6}],
#   'counts_by_year': [{'year': 2022, 'works_count': 0, 'cited_by_count': 511},
#    {'year': 2021, 'works_count': 1, 'cited_by_count': 868},
#    {'year': 2020, 'works_count': 0, 'cited_by_count': 733},
#    {'year': 2019, 'works_count': 1, 'cited_by_count': 719},
#    {'year': 2018, 'works_count': 2, 'cited_by_count': 696},
#    {'year': 2017, 'works_count': 0, 'cited_by_count': 682},
#    {'year': 2016, 'works_count': 3, 'cited_by_count': 351},
#    {'year': 2015, 'works_count': 0, 'cited_by_count': 145},
#    {'year': 2014, 'works_count': 0, 'cited_by_count': 183},
#    {'year': 2013, 'works_count': 0, 'cited_by_count': 135},
#    {'year': 2012, 'works_count': 0, 'cited_by_count': 88}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A3191665970',
#   'updated_date': '2022-08-18T17:17:07.002817',
#   'created_date': '2021-08-16'},
#  {'id': 'https://openalex.org/A3211894982',
#   'orcid': None,
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 2109.9028,
#   'works_count': 50,
#   'cited_by_count': 4035,
#   'ids': {'openalex': 'https://openalex.org/A3211894982', 'mag': '3211894982'},
#   'last_known_institution': {'id': 'https://openalex.org/I1330342723',
#    'ror': 'https://ror.org/02qp3tb03',
#    'display_name': 'Mayo Clinic',
#    'country_code': 'US',
#    'type': 'healthcare'},
#   'x_concepts': [{'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 98.0},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 86.0},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 84.0},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 80.0},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 74.0},
#    {'id': 'https://openalex.org/C134018914',
#     'wikidata': 'https://www.wikidata.org/wiki/Q162606',
#     'display_name': 'Endocrinology',
#     'level': 1,
#     'score': 74.0},
#    {'id': 'https://openalex.org/C95444343',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7141',
#     'display_name': 'Cell biology',
#     'level': 1,
#     'score': 58.0},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': 56.0},
#    {'id': 'https://openalex.org/C90924648',
#     'wikidata': 'https://www.wikidata.org/wiki/Q120569',
#     'display_name': 'Gastroenterology',
#     'level': 1,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C62478195',
#     'wikidata': 'https://www.wikidata.org/wiki/Q828130',
#     'display_name': 'Signal transduction',
#     'level': 2,
#     'score': 42.0},
#    {'id': 'https://openalex.org/C176891718',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1997459',
#     'display_name': 'Hepatic stellate cell',
#     'level': 2,
#     'score': 42.0},
#    {'id': 'https://openalex.org/C2780559512',
#     'wikidata': 'https://www.wikidata.org/wiki/Q605709',
#     'display_name': 'Fibrosis',
#     'level': 2,
#     'score': 42.0},
#    {'id': 'https://openalex.org/C502942594',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3421914',
#     'display_name': 'Cancer research',
#     'level': 1,
#     'score': 40.0},
#    {'id': 'https://openalex.org/C203014093',
#     'wikidata': 'https://www.wikidata.org/wiki/Q101929',
#     'display_name': 'Immunology',
#     'level': 1,
#     'score': 34.0},
#    {'id': 'https://openalex.org/C2777214474',
#     'wikidata': 'https://www.wikidata.org/wiki/Q147778',
#     'display_name': 'Cirrhosis',
#     'level': 2,
#     'score': 34.0},
#    {'id': 'https://openalex.org/C2778539099',
#     'wikidata': 'https://www.wikidata.org/wiki/Q6120',
#     'display_name': 'Hedgehog',
#     'level': 3,
#     'score': 34.0},
#    {'id': 'https://openalex.org/C88498014',
#     'wikidata': 'https://www.wikidata.org/wiki/Q14859918',
#     'display_name': 'Hedgehog signaling pathway',
#     'level': 3,
#     'score': 30.0},
#    {'id': 'https://openalex.org/C170493617',
#     'wikidata': 'https://www.wikidata.org/wiki/Q208467',
#     'display_name': 'Receptor',
#     'level': 2,
#     'score': 30.0},
#    {'id': 'https://openalex.org/C28328180',
#     'wikidata': 'https://www.wikidata.org/wiki/Q48196',
#     'display_name': 'Stem cell',
#     'level': 2,
#     'score': 22.0},
#    {'id': 'https://openalex.org/C141071460',
#     'wikidata': 'https://www.wikidata.org/wiki/Q40821',
#     'display_name': 'Surgery',
#     'level': 1,
#     'score': 22.0}],
#   'counts_by_year': [{'year': 2022, 'works_count': 0, 'cited_by_count': 156},
#    {'year': 2021, 'works_count': 5, 'cited_by_count': 266},
#    {'year': 2020, 'works_count': 2, 'cited_by_count': 269},
#    {'year': 2019, 'works_count': 0, 'cited_by_count': 211},
#    {'year': 2018, 'works_count': 1, 'cited_by_count': 273},
#    {'year': 2017, 'works_count': 1, 'cited_by_count': 332},
#    {'year': 2016, 'works_count': 0, 'cited_by_count': 314},
#    {'year': 2015, 'works_count': 1, 'cited_by_count': 389},
#    {'year': 2014, 'works_count': 2, 'cited_by_count': 323},
#    {'year': 2013, 'works_count': 4, 'cited_by_count': 298},
#    {'year': 2012, 'works_count': 1, 'cited_by_count': 283}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A3211894982',
#   'updated_date': '2022-08-13T21:33:43.634555',
#   'created_date': '2021-11-22'},
#  {'id': 'https://openalex.org/A2201441985',
#   'orcid': 'https://orcid.org/0000-0001-5586-623X',
#   'display_name': 'Yang Liu',
#   'display_name_alternatives': [],
#   'relevance_score': 1861.645,
#   'works_count': 1877,
#   'cited_by_count': 28279,
#   'ids': {'openalex': 'https://openalex.org/A2201441985',
#    'orcid': 'https://orcid.org/0000-0001-5586-623X',
#    'mag': '2201441985'},
#   'last_known_institution': {'id': 'https://openalex.org/I1328775524',
#    'ror': 'https://ror.org/03893we55',
#    'display_name': 'Zhejiang Sci-Tech University',
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 53.4},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 53.3},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 51.2},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 49.9},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 47.7},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 42.1},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 34.6},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 34.6},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 30.8},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 30.1},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 30.0},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 27.4},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': 26.4},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 25.9},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': 25.3},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 22.8}],
#   'counts_by_year': [{'year': 2022, 'works_count': 38, 'cited_by_count': 3159},
#    {'year': 2021, 'works_count': 248, 'cited_by_count': 5231},
#    {'year': 2020, 'works_count': 284, 'cited_by_count': 3876},
#    {'year': 2019, 'works_count': 211, 'cited_by_count': 3297},
#    {'year': 2018, 'works_count': 200, 'cited_by_count': 2176},
#    {'year': 2017, 'works_count': 126, 'cited_by_count': 1768},
#    {'year': 2016, 'works_count': 100, 'cited_by_count': 1709},
#    {'year': 2015, 'works_count': 124, 'cited_by_count': 1459},
#    {'year': 2014, 'works_count': 123, 'cited_by_count': 1208},
#    {'year': 2013, 'works_count': 75, 'cited_by_count': 1036},
#    {'year': 2012, 'works_count': 83, 'cited_by_count': 786}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2201441985',
#   'updated_date': '2022-08-06T20:07:23.934379',
#   'created_date': '2016-06-24'},
#  {'id': 'https://openalex.org/A2269934924',
#   'orcid': None,
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 1718.6869,
#   'works_count': 61,
#   'cited_by_count': 2675,
#   'ids': {'openalex': 'https://openalex.org/A2269934924', 'mag': '2269934924'},
#   'last_known_institution': {'id': 'https://openalex.org/I76569877',
#    'ror': 'https://ror.org/04ct4d772',
#    'display_name': 'Southeast University',
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 98.4},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 96.7},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 91.8},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 91.8},
#    {'id': 'https://openalex.org/C42360764',
#     'wikidata': 'https://www.wikidata.org/wiki/Q83588',
#     'display_name': 'Chemical engineering',
#     'level': 1,
#     'score': 80.3},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 80.3},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 70.5},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 68.9},
#    {'id': 'https://openalex.org/C159985019',
#     'wikidata': 'https://www.wikidata.org/wiki/Q181790',
#     'display_name': 'Composite material',
#     'level': 1,
#     'score': 68.9},
#    {'id': 'https://openalex.org/C171250308',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11468',
#     'display_name': 'Nanotechnology',
#     'level': 1,
#     'score': 67.2},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 63.9},
#    {'id': 'https://openalex.org/C155672457',
#     'wikidata': 'https://www.wikidata.org/wiki/Q61231',
#     'display_name': 'Nanoparticle',
#     'level': 2,
#     'score': 52.5},
#    {'id': 'https://openalex.org/C153294291',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25261',
#     'display_name': 'Meteorology',
#     'level': 1,
#     'score': 50.8},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 50.8},
#    {'id': 'https://openalex.org/C57879066',
#     'wikidata': 'https://www.wikidata.org/wiki/Q41217',
#     'display_name': 'Mechanics',
#     'level': 1,
#     'score': 49.2},
#    {'id': 'https://openalex.org/C204530211',
#     'wikidata': 'https://www.wikidata.org/wiki/Q752823',
#     'display_name': 'Thermal',
#     'level': 2,
#     'score': 49.2},
#    {'id': 'https://openalex.org/C50517652',
#     'wikidata': 'https://www.wikidata.org/wiki/Q179635',
#     'display_name': 'Heat transfer',
#     'level': 2,
#     'score': 47.5},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 47.5},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 45.9},
#    {'id': 'https://openalex.org/C21946209',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1989679',
#     'display_name': 'Nanofluid',
#     'level': 3,
#     'score': 44.3},
#    {'id': 'https://openalex.org/C147789679',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11372',
#     'display_name': 'Physical chemistry',
#     'level': 1,
#     'score': 44.3},
#    {'id': 'https://openalex.org/C120665830',
#     'wikidata': 'https://www.wikidata.org/wiki/Q14620',
#     'display_name': 'Optics',
#     'level': 1,
#     'score': 41.0},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 32.8},
#    {'id': 'https://openalex.org/C191897082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11467',
#     'display_name': 'Metallurgy',
#     'level': 1,
#     'score': 32.8},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 24.6},
#    {'id': 'https://openalex.org/C161790260',
#     'wikidata': 'https://www.wikidata.org/wiki/Q82264',
#     'display_name': 'Catalysis',
#     'level': 2,
#     'score': 23.0},
#    {'id': 'https://openalex.org/C11413529',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#     'display_name': 'Algorithm',
#     'level': 1,
#     'score': 21.3},
#    {'id': 'https://openalex.org/C17525397',
#     'wikidata': 'https://www.wikidata.org/wiki/Q176140',
#     'display_name': 'Electrode',
#     'level': 2,
#     'score': 21.3},
#    {'id': 'https://openalex.org/C97346530',
#     'wikidata': 'https://www.wikidata.org/wiki/Q487005',
#     'display_name': 'Thermal conductivity',
#     'level': 2,
#     'score': 21.3},
#    {'id': 'https://openalex.org/C104779481',
#     'wikidata': 'https://www.wikidata.org/wiki/Q50707',
#     'display_name': 'Composite number',
#     'level': 2,
#     'score': 21.3}],
#   'counts_by_year': [{'year': 2022, 'works_count': 2, 'cited_by_count': 326},
#    {'year': 2021, 'works_count': 6, 'cited_by_count': 570},
#    {'year': 2020, 'works_count': 5, 'cited_by_count': 518},
#    {'year': 2019, 'works_count': 4, 'cited_by_count': 424},
#    {'year': 2018, 'works_count': 5, 'cited_by_count': 255},
#    {'year': 2017, 'works_count': 8, 'cited_by_count': 213},
#    {'year': 2016, 'works_count': 0, 'cited_by_count': 127},
#    {'year': 2015, 'works_count': 4, 'cited_by_count': 103},
#    {'year': 2014, 'works_count': 9, 'cited_by_count': 63},
#    {'year': 2013, 'works_count': 4, 'cited_by_count': 26},
#    {'year': 2012, 'works_count': 6, 'cited_by_count': 17}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2269934924',
#   'updated_date': '2022-08-07T19:13:58.180783',
#   'created_date': '2016-06-24'},
#  {'id': 'https://openalex.org/A3070923379',
#   'orcid': 'https://orcid.org/0000-0003-0308-7642',
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 1699.3026,
#   'works_count': 43,
#   'cited_by_count': 2615,
#   'ids': {'openalex': 'https://openalex.org/A3070923379',
#    'orcid': 'https://orcid.org/0000-0003-0308-7642',
#    'mag': '3070923379'},
#   'last_known_institution': {'id': 'https://openalex.org/I148099405',
#    'ror': 'https://ror.org/04v2j2k71',
#    'display_name': "Xi'an University of Architecture and Technology",
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 93.0},
#    {'id': 'https://openalex.org/C39432304',
#     'wikidata': 'https://www.wikidata.org/wiki/Q188847',
#     'display_name': 'Environmental science',
#     'level': 0,
#     'score': 90.7},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 90.7},
#    {'id': 'https://openalex.org/C153294291',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25261',
#     'display_name': 'Meteorology',
#     'level': 1,
#     'score': 79.1},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 74.4},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 72.1},
#    {'id': 'https://openalex.org/C18903297',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#     'display_name': 'Ecology',
#     'level': 1,
#     'score': 69.8},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 65.1},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 55.8},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 55.8},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': 55.8},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 53.5},
#    {'id': 'https://openalex.org/C49204034',
#     'wikidata': 'https://www.wikidata.org/wiki/Q52139',
#     'display_name': 'Climatology',
#     'level': 1,
#     'score': 53.5},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 53.5},
#    {'id': 'https://openalex.org/C95457728',
#     'wikidata': 'https://www.wikidata.org/wiki/Q309',
#     'display_name': 'History',
#     'level': 0,
#     'score': 51.2},
#    {'id': 'https://openalex.org/C166957645',
#     'wikidata': 'https://www.wikidata.org/wiki/Q23498',
#     'display_name': 'Archaeology',
#     'level': 1,
#     'score': 51.2},
#    {'id': 'https://openalex.org/C191935318',
#     'wikidata': 'https://www.wikidata.org/wiki/Q148',
#     'display_name': 'China',
#     'level': 2,
#     'score': 48.8},
#    {'id': 'https://openalex.org/C91586092',
#     'wikidata': 'https://www.wikidata.org/wiki/Q757520',
#     'display_name': 'Atmospheric sciences',
#     'level': 1,
#     'score': 46.5},
#    {'id': 'https://openalex.org/C119599485',
#     'wikidata': 'https://www.wikidata.org/wiki/Q43035',
#     'display_name': 'Electrical engineering',
#     'level': 1,
#     'score': 46.5},
#    {'id': 'https://openalex.org/C105795698',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#     'display_name': 'Statistics',
#     'level': 1,
#     'score': 37.2},
#    {'id': 'https://openalex.org/C2994141226',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5142421',
#     'display_name': 'Cold winter',
#     'level': 2,
#     'score': 32.6},
#    {'id': 'https://openalex.org/C78519656',
#     'wikidata': 'https://www.wikidata.org/wiki/Q101333',
#     'display_name': 'Mechanical engineering',
#     'level': 1,
#     'score': 30.2},
#    {'id': 'https://openalex.org/C2992321014',
#     'wikidata': 'https://www.wikidata.org/wiki/Q64624502',
#     'display_name': 'Cold climate',
#     'level': 2,
#     'score': 27.9},
#    {'id': 'https://openalex.org/C100970517',
#     'wikidata': 'https://www.wikidata.org/wiki/Q52107',
#     'display_name': 'Physical geography',
#     'level': 1,
#     'score': 25.6},
#    {'id': 'https://openalex.org/C111368507',
#     'wikidata': 'https://www.wikidata.org/wiki/Q43518',
#     'display_name': 'Oceanography',
#     'level': 1,
#     'score': 25.6},
#    {'id': 'https://openalex.org/C2780165032',
#     'wikidata': 'https://www.wikidata.org/wiki/Q16869822',
#     'display_name': 'Energy consumption',
#     'level': 2,
#     'score': 25.6},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C147176958',
#     'wikidata': 'https://www.wikidata.org/wiki/Q77590',
#     'display_name': 'Civil engineering',
#     'level': 1,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C170154142',
#     'wikidata': 'https://www.wikidata.org/wiki/Q150737',
#     'display_name': 'Architectural engineering',
#     'level': 1,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C186370098',
#     'wikidata': 'https://www.wikidata.org/wiki/Q442787',
#     'display_name': 'Energy (signal processing)',
#     'level': 2,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C204530211',
#     'wikidata': 'https://www.wikidata.org/wiki/Q752823',
#     'display_name': 'Thermal',
#     'level': 2,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C103742991',
#     'wikidata': 'https://www.wikidata.org/wiki/Q173725',
#     'display_name': 'Air conditioning',
#     'level': 2,
#     'score': 20.9},
#    {'id': 'https://openalex.org/C541104983',
#     'wikidata': 'https://www.wikidata.org/wiki/Q40015',
#     'display_name': 'Solar energy',
#     'level': 2,
#     'score': 20.9}],
#   'counts_by_year': [{'year': 2022, 'works_count': 0, 'cited_by_count': 181},
#    {'year': 2021, 'works_count': 1, 'cited_by_count': 369},
#    {'year': 2020, 'works_count': 4, 'cited_by_count': 306},
#    {'year': 2019, 'works_count': 0, 'cited_by_count': 338},
#    {'year': 2018, 'works_count': 2, 'cited_by_count': 256},
#    {'year': 2017, 'works_count': 4, 'cited_by_count': 212},
#    {'year': 2016, 'works_count': 1, 'cited_by_count': 186},
#    {'year': 2015, 'works_count': 1, 'cited_by_count': 201},
#    {'year': 2014, 'works_count': 2, 'cited_by_count': 164},
#    {'year': 2013, 'works_count': 2, 'cited_by_count': 129},
#    {'year': 2012, 'works_count': 2, 'cited_by_count': 89}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A3070923379',
#   'updated_date': '2022-08-06T22:17:58.008912',
#   'created_date': '2020-08-24'},
#  {'id': 'https://openalex.org/A2580614851',
#   'orcid': None,
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 1491.5543,
#   'works_count': 4,
#   'cited_by_count': 2017,
#   'ids': {'openalex': 'https://openalex.org/A2580614851', 'mag': '2580614851'},
#   'last_known_institution': {'id': 'https://openalex.org/I145311948',
#    'ror': 'https://ror.org/00za53h95',
#    'display_name': 'Johns Hopkins University',
#    'country_code': 'US',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C46141821',
#     'wikidata': 'https://www.wikidata.org/wiki/Q209402',
#     'display_name': 'Nuclear magnetic resonance',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C147897179',
#     'wikidata': 'https://www.wikidata.org/wiki/Q407828',
#     'display_name': 'Topoisomerase',
#     'level': 3,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C153911025',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7202',
#     'display_name': 'Molecular biology',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C181199279',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8047',
#     'display_name': 'Enzyme',
#     'level': 2,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C202751555',
#     'wikidata': 'https://www.wikidata.org/wiki/Q221681',
#     'display_name': 'In vitro',
#     'level': 2,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C552990157',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7430',
#     'display_name': 'DNA',
#     'level': 2,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': 75.0},
#    {'id': 'https://openalex.org/C43369102',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2307625',
#     'display_name': 'Fracture (geology)',
#     'level': 2,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C141071460',
#     'wikidata': 'https://www.wikidata.org/wiki/Q40821',
#     'display_name': 'Surgery',
#     'level': 1,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C151730666',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7205',
#     'display_name': 'Paleontology',
#     'level': 1,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C159985019',
#     'wikidata': 'https://www.wikidata.org/wiki/Q181790',
#     'display_name': 'Composite material',
#     'level': 1,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C175156509',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1990218',
#     'display_name': 'Cleavage (geology)',
#     'level': 3,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C187320778',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1349130',
#     'display_name': 'Geotechnical engineering',
#     'level': 1,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C2776694085',
#     'wikidata': 'https://www.wikidata.org/wiki/Q974135',
#     'display_name': 'Chemotherapy',
#     'level': 2,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C19014433',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5130995',
#     'display_name': 'Cleave',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C24107716',
#     'wikidata': 'https://www.wikidata.org/wiki/Q123619',
#     'display_name': 'Nucleic acid',
#     'level': 2,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C31254050',
#     'wikidata': 'https://www.wikidata.org/wiki/Q22328799',
#     'display_name': 'DNA clamp',
#     'level': 5,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C38441620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q863983',
#     'display_name': 'Phosphodiester bond',
#     'level': 4,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C49105822',
#     'wikidata': 'https://www.wikidata.org/wiki/Q176996',
#     'display_name': 'Polymerase chain reaction',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C67705224',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11053',
#     'display_name': 'RNA',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C73573662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q130996',
#     'display_name': 'DNA replication',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C83640560',
#     'wikidata': 'https://www.wikidata.org/wiki/Q180951',
#     'display_name': 'Chromatin',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C143425029',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5205747',
#     'display_name': 'DNA damage',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C158456008',
#     'wikidata': 'https://www.wikidata.org/wiki/Q412639',
#     'display_name': 'DNA supercoil',
#     'level': 4,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C167125095',
#     'wikidata': 'https://www.wikidata.org/wiki/Q70551687',
#     'display_name': 'DNA gyrase',
#     'level': 4,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C180577832',
#     'wikidata': 'https://www.wikidata.org/wiki/Q127920',
#     'display_name': 'Covalent bond',
#     'level': 2,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C185581394',
#     'wikidata': 'https://www.wikidata.org/wiki/Q145911',
#     'display_name': 'Base pair',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C547475151',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25419',
#     'display_name': 'Escherichia coli',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C2778119113',
#     'wikidata': 'https://www.wikidata.org/wiki/Q418817',
#     'display_name': 'Etoposide',
#     'level': 3,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C2781303535',
#     'wikidata': 'https://www.wikidata.org/wiki/Q18936',
#     'display_name': 'Doxorubicin',
#     'level': 3,
#     'score': 25.0}],
#   'counts_by_year': [{'year': 2022, 'works_count': 0, 'cited_by_count': 30},
#    {'year': 2021, 'works_count': 0, 'cited_by_count': 57},
#    {'year': 2020, 'works_count': 0, 'cited_by_count': 53},
#    {'year': 2019, 'works_count': 0, 'cited_by_count': 61},
#    {'year': 2018, 'works_count': 0, 'cited_by_count': 49},
#    {'year': 2017, 'works_count': 0, 'cited_by_count': 53},
#    {'year': 2016, 'works_count': 0, 'cited_by_count': 70},
#    {'year': 2015, 'works_count': 0, 'cited_by_count': 39},
#    {'year': 2014, 'works_count': 0, 'cited_by_count': 47},
#    {'year': 2013, 'works_count': 0, 'cited_by_count': 51},
#    {'year': 2012, 'works_count': 0, 'cited_by_count': 64}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2580614851',
#   'updated_date': '2022-08-05T06:00:33.286577',
#   'created_date': '2017-02-03'},
#  {'id': 'https://openalex.org/A2301576102',
#   'orcid': 'https://orcid.org/0000-0001-7961-4854',
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 1487.9628,
#   'works_count': 151,
#   'cited_by_count': 2005,
#   'ids': {'openalex': 'https://openalex.org/A2301576102',
#    'orcid': 'https://orcid.org/0000-0001-7961-4854',
#    'mag': '2301576102'},
#   'last_known_institution': {'id': 'https://openalex.org/I76130692',
#    'ror': 'https://ror.org/00a2xv884',
#    'display_name': 'Zhejiang University',
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 84.8},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 80.8},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 64.9},
#    {'id': 'https://openalex.org/C159985019',
#     'wikidata': 'https://www.wikidata.org/wiki/Q181790',
#     'display_name': 'Composite material',
#     'level': 1,
#     'score': 60.9},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 59.6},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 58.9},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 55.6},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 53.0},
#    {'id': 'https://openalex.org/C153294291',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25261',
#     'display_name': 'Meteorology',
#     'level': 1,
#     'score': 52.3},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 49.7},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 47.7},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 47.0},
#    {'id': 'https://openalex.org/C39432304',
#     'wikidata': 'https://www.wikidata.org/wiki/Q188847',
#     'display_name': 'Environmental science',
#     'level': 0,
#     'score': 43.7},
#    {'id': 'https://openalex.org/C146978453',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3798668',
#     'display_name': 'Aerospace engineering',
#     'level': 1,
#     'score': 39.7},
#    {'id': 'https://openalex.org/C177229083',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5861',
#     'display_name': 'Glass fiber',
#     'level': 2,
#     'score': 36.4},
#    {'id': 'https://openalex.org/C18903297',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#     'display_name': 'Ecology',
#     'level': 1,
#     'score': 35.8},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 33.8},
#    {'id': 'https://openalex.org/C204530211',
#     'wikidata': 'https://www.wikidata.org/wiki/Q752823',
#     'display_name': 'Thermal',
#     'level': 2,
#     'score': 31.1},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 30.5},
#    {'id': 'https://openalex.org/C191897082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11467',
#     'display_name': 'Metallurgy',
#     'level': 1,
#     'score': 27.2},
#    {'id': 'https://openalex.org/C11413529',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#     'display_name': 'Algorithm',
#     'level': 1,
#     'score': 26.5},
#    {'id': 'https://openalex.org/C104779481',
#     'wikidata': 'https://www.wikidata.org/wiki/Q50707',
#     'display_name': 'Composite number',
#     'level': 2,
#     'score': 24.5}],
#   'counts_by_year': [{'year': 2022, 'works_count': 5, 'cited_by_count': 364},
#    {'year': 2021, 'works_count': 19, 'cited_by_count': 529},
#    {'year': 2020, 'works_count': 27, 'cited_by_count': 343},
#    {'year': 2019, 'works_count': 23, 'cited_by_count': 258},
#    {'year': 2018, 'works_count': 15, 'cited_by_count': 144},
#    {'year': 2017, 'works_count': 5, 'cited_by_count': 90},
#    {'year': 2016, 'works_count': 14, 'cited_by_count': 87},
#    {'year': 2015, 'works_count': 10, 'cited_by_count': 70},
#    {'year': 2014, 'works_count': 11, 'cited_by_count': 45},
#    {'year': 2013, 'works_count': 6, 'cited_by_count': 26},
#    {'year': 2012, 'works_count': 7, 'cited_by_count': 22}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2301576102',
#   'updated_date': '2022-08-12T23:38:24.637414',
#   'created_date': '2016-06-24'},
#  {'id': 'https://openalex.org/A3190698607',
#   'orcid': None,
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 1422.2234,
#   'works_count': 4,
#   'cited_by_count': 1837,
#   'ids': {'openalex': 'https://openalex.org/A3190698607', 'mag': '3190698607'},
#   'last_known_institution': {'id': 'https://openalex.org/I4210122201',
#    'ror': 'https://ror.org/02ndk3y82',
#    'display_name': "Children's Medical Center",
#    'country_code': 'US',
#    'type': 'healthcare'},
#   'x_concepts': [{'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
# ...
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 74.0},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 61.6},
#    {'id': 'https://openalex.org/C95444343',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7141',
#     'display_name': 'Cell biology',
#     'level': 1,
#     'score': 52.1},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': 41.1},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 37.0},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 35.6},
#    {'id': 'https://openalex.org/C134018914',
#     'wikidata': 'https://www.wikidata.org/wiki/Q162606',
#     'display_name': 'Endocrinology',
#     'level': 1,
#     'score': 35.6},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 35.6},
#    {'id': 'https://openalex.org/C190283241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q14599311',
#     'display_name': 'Apoptosis',
#     'level': 2,
#     'score': 35.6},
#    {'id': 'https://openalex.org/C203014093',
#     'wikidata': 'https://www.wikidata.org/wiki/Q101929',
#     'display_name': 'Immunology',
#     'level': 1,
#     'score': 28.8},
#    {'id': 'https://openalex.org/C502942594',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3421914',
#     'display_name': 'Cancer research',
#     'level': 1,
#     'score': 27.4},
#    {'id': 'https://openalex.org/C46141821',
#     'wikidata': 'https://www.wikidata.org/wiki/Q209402',
#     'display_name': 'Nuclear magnetic resonance',
#     'level': 1,
#     'score': 26.0},
#    {'id': 'https://openalex.org/C121608353',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12078',
#     'display_name': 'Cancer',
#     'level': 2,
#     'score': 23.3},
#    {'id': 'https://openalex.org/C171089720',
#     'wikidata': 'https://www.wikidata.org/wiki/Q193583',
#     'display_name': 'Adipose tissue',
#     'level': 2,
#     'score': 20.5}],
#   'counts_by_year': [{'year': 2022, 'works_count': 3, 'cited_by_count': 738},
#    {'year': 2021, 'works_count': 6, 'cited_by_count': 1362},
#    {'year': 2020, 'works_count': 6, 'cited_by_count': 1153},
#    {'year': 2019, 'works_count': 2, 'cited_by_count': 1225},
#    {'year': 2018, 'works_count': 4, 'cited_by_count': 987},
#    {'year': 2017, 'works_count': 6, 'cited_by_count': 1005},
#    {'year': 2016, 'works_count': 10, 'cited_by_count': 605},
#    {'year': 2015, 'works_count': 19, 'cited_by_count': 293},
#    {'year': 2014, 'works_count': 4, 'cited_by_count': 257},
#    {'year': 2013, 'works_count': 8, 'cited_by_count': 158},
#    {'year': 2012, 'works_count': 0, 'cited_by_count': 102}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A3158501833',
#   'updated_date': '2022-08-07T16:12:15.123234',
#   'created_date': '2021-05-10'},
#  {'id': 'https://openalex.org/A2805274385',
#   'orcid': 'https://orcid.org/0000-0001-9182-8038',
#   'display_name': 'Yang Liu',
#   'display_name_alternatives': [],
#   'relevance_score': 945.85876,
#   'works_count': 163,
#   'cited_by_count': 7300,
#   'ids': {'openalex': 'https://openalex.org/A2805274385',
#    'orcid': 'https://orcid.org/0000-0001-9182-8038',
#    'mag': '2805274385'},
#   'last_known_institution': {'id': 'https://openalex.org/I126744593',
#    'ror': 'https://ror.org/04rq5mt64',
#    'display_name': 'University of Maryland, Baltimore',
#    'country_code': 'US',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 95.7},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 92.7},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 82.9},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 81.7},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 80.5},
#    {'id': 'https://openalex.org/C203014093',
#     'wikidata': 'https://www.wikidata.org/wiki/Q101929',
#     'display_name': 'Immunology',
#     'level': 1,
#     'score': 61.6},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 57.9},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': 53.7},
#    {'id': 'https://openalex.org/C8891405',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1059',
#     'display_name': 'Immune system',
#     'level': 2,
#     'score': 48.2},
#    {'id': 'https://openalex.org/C202751555',
#     'wikidata': 'https://www.wikidata.org/wiki/Q221681',
#     'display_name': 'In vitro',
#     'level': 2,
#     'score': 37.8},
#    {'id': 'https://openalex.org/C95444343',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7141',
#     'display_name': 'Cell biology',
#     'level': 1,
#     'score': 37.2},
#    {'id': 'https://openalex.org/C502942594',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3421914',
#     'display_name': 'Cancer research',
#     'level': 1,
#     'score': 32.3},
#    {'id': 'https://openalex.org/C147483822',
#     'wikidata': 'https://www.wikidata.org/wiki/Q103537',
#     'display_name': 'Antigen',
#     'level': 2,
#     'score': 31.7},
#    {'id': 'https://openalex.org/C154317977',
#     'wikidata': 'https://www.wikidata.org/wiki/Q376266',
#     'display_name': 'Cytotoxic T cell',
#     'level': 3,
#     'score': 30.5},
#    {'id': 'https://openalex.org/C2776090121',
#     'wikidata': 'https://www.wikidata.org/wiki/Q193529',
#     'display_name': 'T cell',
#     'level': 3,
#     'score': 29.3},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 27.4},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 26.2},
#    {'id': 'https://openalex.org/C151730666',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7205',
#     'display_name': 'Paleontology',
#     'level': 1,
#     'score': 26.2},
#    {'id': 'https://openalex.org/C89423630',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7193',
#     'display_name': 'Microbiology',
#     'level': 1,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C121608353',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12078',
#     'display_name': 'Cancer',
#     'level': 2,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C523546767',
#     'wikidata': 'https://www.wikidata.org/wiki/Q10876',
#     'display_name': 'Bacteria',
#     'level': 2,
#     'score': 24.4},
#    {'id': 'https://openalex.org/C167672396',
#     'wikidata': 'https://www.wikidata.org/wiki/Q417800',
#     'display_name': 'CD8',
#     'level': 3,
#     'score': 22.6},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 20.1}],
#   'counts_by_year': [{'year': 2022, 'works_count': 4, 'cited_by_count': 654},
#    {'year': 2021, 'works_count': 23, 'cited_by_count': 1089},
#    {'year': 2020, 'works_count': 18, 'cited_by_count': 687},
#    {'year': 2019, 'works_count': 5, 'cited_by_count': 581},
#    {'year': 2018, 'works_count': 2, 'cited_by_count': 396},
#    {'year': 2017, 'works_count': 9, 'cited_by_count': 407},
#    {'year': 2016, 'works_count': 10, 'cited_by_count': 357},
#    {'year': 2015, 'works_count': 8, 'cited_by_count': 349},
#    {'year': 2014, 'works_count': 7, 'cited_by_count': 268},
#    {'year': 2013, 'works_count': 6, 'cited_by_count': 272},
#    {'year': 2012, 'works_count': 3, 'cited_by_count': 202}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2805274385',
#   'updated_date': '2022-08-06T04:58:50.540207',
#   'created_date': '2018-06-13'},
#  {'id': 'https://openalex.org/A2579690888',
#   'orcid': None,
#   'display_name': 'Liu Yang',
#   'display_name_alternatives': [],
#   'relevance_score': 933.8472,
#   'works_count': 11,
#   'cited_by_count': 792,
#   'ids': {'openalex': 'https://openalex.org/A2579690888', 'mag': '2579690888'},
#   'last_known_institution': {'id': 'https://openalex.org/I99065089',
#    'ror': 'https://ror.org/03cve4549',
#    'display_name': 'Tsinghua University',
#    'country_code': 'CN',
#    'type': 'education'},
#   'x_concepts': [{'id': 'https://openalex.org/C39432304',
#     'wikidata': 'https://www.wikidata.org/wiki/Q188847',
#     'display_name': 'Environmental science',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C18903297',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#     'display_name': 'Ecology',
#     'level': 1,
#     'score': 90.9},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 90.9},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 90.9},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 81.8},
#    {'id': 'https://openalex.org/C95457728',
#     'wikidata': 'https://www.wikidata.org/wiki/Q309',
#     'display_name': 'History',
#     'level': 0,
#     'score': 81.8},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 81.8},
#    {'id': 'https://openalex.org/C166957645',
#     'wikidata': 'https://www.wikidata.org/wiki/Q23498',
#     'display_name': 'Archaeology',
#     'level': 1,
#     'score': 81.8},
#    {'id': 'https://openalex.org/C191935318',
#     'wikidata': 'https://www.wikidata.org/wiki/Q148',
#     'display_name': 'China',
#     'level': 2,
#     'score': 81.8},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': 81.8},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 72.7},
#    {'id': 'https://openalex.org/C2778304055',
#     'wikidata': 'https://www.wikidata.org/wiki/Q657474',
#     'display_name': 'Beijing',
#     'level': 3,
#     'score': 72.7},
#    {'id': 'https://openalex.org/C24245907',
#     'wikidata': 'https://www.wikidata.org/wiki/Q498957',
#     'display_name': 'Particulates',
#     'level': 2,
#     'score': 63.6},
#    {'id': 'https://openalex.org/C91586092',
#     'wikidata': 'https://www.wikidata.org/wiki/Q757520',
#     'display_name': 'Atmospheric sciences',
#     'level': 1,
#     'score': 63.6},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 63.6},
#    {'id': 'https://openalex.org/C107872376',
#     'wikidata': 'https://www.wikidata.org/wiki/Q321355',
#     'display_name': 'Environmental chemistry',
#     'level': 1,
#     'score': 63.6},
#    {'id': 'https://openalex.org/C153294291',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25261',
#     'display_name': 'Meteorology',
#     'level': 1,
#     'score': 63.6},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 54.5},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 54.5},
#    {'id': 'https://openalex.org/C147789679',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11372',
#     'display_name': 'Physical chemistry',
#     'level': 1,
#     'score': 45.5},
#    {'id': 'https://openalex.org/C548081761',
#     'wikidata': 'https://www.wikidata.org/wiki/Q180388',
#     'display_name': 'Waste management',
#     'level': 1,
#     'score': 45.5},
#    {'id': 'https://openalex.org/C87717796',
#     'wikidata': 'https://www.wikidata.org/wiki/Q146326',
#     'display_name': 'Environmental engineering',
#     'level': 1,
#     'score': 36.4},
#    {'id': 'https://openalex.org/C126314574',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2364111',
#     'display_name': 'Air quality index',
#     'level': 2,
#     'score': 36.4},
#    {'id': 'https://openalex.org/C159985019',
#     'wikidata': 'https://www.wikidata.org/wiki/Q181790',
#     'display_name': 'Composite material',
#     'level': 1,
#     'score': 36.4},
#    {'id': 'https://openalex.org/C559116025',
#     'wikidata': 'https://www.wikidata.org/wiki/Q131123',
#     'display_name': 'Air pollution',
#     'level': 2,
#     'score': 36.4},
#    {'id': 'https://openalex.org/C2779345167',
#     'wikidata': 'https://www.wikidata.org/wiki/Q104541',
#     'display_name': 'Aerosol',
#     'level': 2,
#     'score': 36.4},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 27.3},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 27.3},
#    {'id': 'https://openalex.org/C82685317',
#     'wikidata': 'https://www.wikidata.org/wiki/Q19829510',
#     'display_name': 'Pollutant',
#     'level': 2,
#     'score': 27.3},
#    {'id': 'https://openalex.org/C126857682',
#     'wikidata': 'https://www.wikidata.org/wiki/Q589446',
#     'display_name': 'Mass concentration (chemistry)',
#     'level': 2,
#     'score': 27.3},
#    {'id': 'https://openalex.org/C145148216',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36496',
#     'display_name': 'Ion',
#     'level': 2,
#     'score': 27.3},
#    {'id': 'https://openalex.org/C158787203',
#     'wikidata': 'https://www.wikidata.org/wiki/Q900291',
#     'display_name': 'Total organic carbon',
#     'level': 2,
#     'score': 27.3}],
#   'counts_by_year': [{'year': 2022, 'works_count': 0, 'cited_by_count': 34},
#    {'year': 2021, 'works_count': 0, 'cited_by_count': 61},
#    {'year': 2020, 'works_count': 0, 'cited_by_count': 79},
#    {'year': 2019, 'works_count': 0, 'cited_by_count': 83},
#    {'year': 2018, 'works_count': 0, 'cited_by_count': 74},
#    {'year': 2017, 'works_count': 0, 'cited_by_count': 86},
#    {'year': 2016, 'works_count': 0, 'cited_by_count': 79},
#    {'year': 2015, 'works_count': 2, 'cited_by_count': 82},
#    {'year': 2014, 'works_count': 3, 'cited_by_count': 59},
#    {'year': 2013, 'works_count': 1, 'cited_by_count': 41},
#    {'year': 2012, 'works_count': 2, 'cited_by_count': 44}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A2579690888',
#   'updated_date': '2022-08-08T03:31:30.827587',
#   'created_date': '2017-01-26'}]
