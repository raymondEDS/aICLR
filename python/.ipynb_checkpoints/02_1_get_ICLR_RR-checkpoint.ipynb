# %%
import openreview
import pandas as pd
import datetime as date
import tqdm

# %%
df_submissions = pd.read_csv('./data/submissions/df_submissions.csv')
client = openreview.Client(baseurl='https://api.openreview.net')

# %%
#takes about 10 minutes
list_all_notes = [client.get_notes(forum =forum) for forum in tqdm.tqdm(df_submissions.forum.tolist())]
# Out:
# 100%|███████████████████████████████████████| 2820/2820 [17:00<00:00,  2.76it/s]

# %%
list_all_notes = [item for sublist in list_all_notes for item in sublist]
list_all_notes = [note.__dict__ for note in list_all_notes]

# %%
df_all_notes = pd.DataFrame(list_all_notes)
df_all_notes = pd.concat([df_all_notes, df_all_notes.content.apply(pd.Series)],axis = 1)
df_all_notes = df_all_notes.drop(columns=['content'])

# %%
def find_rr(row):
    row = row['invitation']
    row = row.lower()
    if (row.find('official') != -1):
        return 1
    else:
        return 0
    
def find_meta_review(row):
    row = row['invitation']
    row = row.lower()
    if (row.find('meta') != -1):
        return 1
    else:
        return 0

    

def find_year(row):
    row = row['invitation']
    x = row.split('/')
    return x[1]
    
    
#df_all_notes.invitation.str.rsplit(pat='/', n = 2,expand=True)

tqdm.tqdm.pandas()
df_all_notes['rr_flag'] = df_all_notes.progress_apply(lambda x: find_rr(x),axis=1)
df_all_notes['meta_flag'] = df_all_notes.progress_apply(lambda x: find_meta_review(x),axis=1)
df_all_notes['year'] = df_all_notes.progress_apply(lambda x: find_year(x),axis=1)
# Out:
# 100%|█████████████████████████████████| 35487/35487 [00:00<00:00, 131812.21it/s]
# 100%|█████████████████████████████████| 35487/35487 [00:00<00:00, 153520.89it/s]
# 100%|█████████████████████████████████| 35487/35487 [00:00<00:00, 157533.11it/s]

# %%
df_all_notes.to_csv('./data/submissions/df_all_notes.csv',index=False)

# %%
df_all_notes.columns
# Out:
# Index(['id', 'original', 'number', 'cdate', 'mdate', 'tcdate', 'tmdate',
#        'ddate', 'forum', 'referent', 'invitation', 'replyto', 'readers',
#        'nonreaders', 'signatures', 'writers', 'details', 'TL;DR', 'title',
#        'abstract', 'pdf', 'keywords', 'authors', 'conflicts', 'authorids',
#        'venue', 'venueid', '_bibtex', 'paperhash', 'comment', 'rating',
#        'review', 'confidence', 'question', 'decision', 'author_emails', 'code',
#        'data', 'metareview', 'recommendation', 'withdrawal confirmation',
#        'rr_flag', 'meta_flag', 'year'],
#       dtype='object')

# %%
test  =df_all_notes[df_all_notes['meta_flag'] == 1]

# %%
test[['year','review','comment','invitation']]
# Out:
#        year                                             review  \
# 1      2017                                                NaN
# 3      2017  This paper proposes a new architecture that do...
# 4      2017                                                NaN
# 6      2017                                                NaN
# 8      2017  This paper proposes a design principle for com...
# ...     ...                                                ...
# 35480  2019                                                NaN
# 35481  2019  The paper proposes a method for learning embed...
# 35482  2019  This paper proposes a soft relaxation of the b...
# 35483  2019                                                NaN
# 35485  2019  Post-rebuttal revision: All my concerns were a...
#
#                                                  comment  \
# 1      I thank the authors for their response and exp...
# 3                                                    NaN
# 4      Authors claim that the reviewers reflect "narr...
# 6      - Number of parameters needed is dramatically ...
# 8                                                    NaN
# ...                                                  ...
# 35480  Thank you for the thoughtful review.\n\n - We ...
# 35481                                                NaN
# 35482                                                NaN
# 35483  Hi, thanks for the comment! We actually do cit...
# 35485                                                NaN
#
#                                               invitation
# 1      ICLR.cc/2017/conference/-/paper214/official/co...
# 3      ICLR.cc/2017/conference/-/paper214/official/re...
# 4      ICLR.cc/2017/conference/-/paper214/official/co...
# 6      ICLR.cc/2017/conference/-/paper214/official/co...
# 8      ICLR.cc/2017/conference/-/paper214/official/re...
# ...                                                  ...
# 35480  ICLR.cc/2019/Conference/-/Paper1/Official_Comment
# 35481   ICLR.cc/2019/Conference/-/Paper1/Official_Review
# 35482   ICLR.cc/2019/Conference/-/Paper1/Official_Review
# 35483  ICLR.cc/2019/Conference/-/Paper1/Official_Comment
# 35485   ICLR.cc/2019/Conference/-/Paper1/Official_Review
#
# [22878 rows x 4 columns]

# %%
df_all_notes = pd.read_csv('../data/submissions/df_all_notes.csv')
# Out:
# /var/folders/v9/8whxr3fd1mv_pwkjh0kn920m0000gn/T/ipykernel_97056/1467377078.py:1: DtypeWarning: Columns (23,25,26,33,34,35,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all_notes = pd.read_csv('../data/submissions/df_all_notes.csv')

# %%
df_all_notes[df_all_notes['invitation'].str.contains('official')]
# Out:
#              id original  number  cdate  mdate         tcdate         tmdate  \
# 1     SJkBY2yve      NaN       4    NaN    NaN  1484929335077  1484929335077
# 3     r1tPX1rVg      NaN       2    NaN    NaN  1482122080695  1482122080695
# 4     ryKsOZQvl      NaN       5    NaN    NaN  1485146273283  1485146273283
# 6     HJYdQPeme      NaN       2    NaN    NaN  1480778608772  1480778608779
# 8     rkUFJWfNl      NaN       1    NaN    NaN  1481932670179  1484928792294
# ...         ...      ...     ...    ...    ...            ...            ...
# 7458  BJLW1aJ7e      NaN       1    NaN    NaN  1480736509588  1480736509592
# 7462  H1BxzUzVl      NaN       1    NaN    NaN  1481953773328  1481953773328
# 7463  Hk2oimlSe      NaN       3    NaN    NaN  1482861475737  1482861475737
# 7465  ByXsQisNe      NaN       3    NaN    NaN  1482564507220  1482564507220
# 7475  S1h7tgZEx      NaN       2    NaN    NaN  1481865507814  1481865507814
#
#       ddate      forum  referent  ... decision author_emails code data  \
# 1       NaN  S1VaB4cex       NaN  ...      NaN           NaN  NaN  NaN
# 3       NaN  S1VaB4cex       NaN  ...      NaN           NaN  NaN  NaN
# 4       NaN  S1VaB4cex       NaN  ...      NaN           NaN  NaN  NaN
# 6       NaN  S1VaB4cex       NaN  ...      NaN           NaN  NaN  NaN
# 8       NaN  S1VaB4cex       NaN  ...      NaN           NaN  NaN  NaN
# ...     ...        ...       ...  ...      ...           ...  ...  ...
# 7458    NaN  B1kJ6H9ex       NaN  ...      NaN           NaN  NaN  NaN
# 7462    NaN  B1kJ6H9ex       NaN  ...      NaN           NaN  NaN  NaN
# 7463    NaN  B1kJ6H9ex       NaN  ...      NaN           NaN  NaN  NaN
# 7465    NaN  B1akgy9xx       NaN  ...      NaN           NaN  NaN  NaN
# 7475    NaN  B1akgy9xx       NaN  ...      NaN           NaN  NaN  NaN
#
#      metareview recommendation  withdrawal confirmation rr_flag meta_flag  \
# 1           NaN            NaN                      NaN       1         0
# 3           NaN            NaN                      NaN       1         0
# 4           NaN            NaN                      NaN       1         0
# 6           NaN            NaN                      NaN       1         0
# 8           NaN            NaN                      NaN       1         0
# ...         ...            ...                      ...     ...       ...
# 7458        NaN            NaN                      NaN       1         0
# 7462        NaN            NaN                      NaN       1         0
# 7463        NaN            NaN                      NaN       1         0
# 7465        NaN            NaN                      NaN       1         0
# 7475        NaN            NaN                      NaN       1         0
#
#       year
# 1     2017
# 3     2017
# 4     2017
# 6     2017
# 8     2017
# ...    ...
# 7458  2017
# 7462  2017
# 7463  2017
# 7465  2017
# 7475  2017
#
# [1889 rows x 44 columns]

# %%
df_all_notes[df_all_notes['rr_flag'] == 1 & df_all_notes[]]

# %%
df_convokit = df_all_notes[df_all_notes['rr_flag'] == 1]
df_convokit = df_convokit[['id','tcdate','comment','review','signatures','replyto','forum','year']]
df_convokit['text'] = df_all_notes['comment'].fillna('')  + df_all_notes['review'].fillna('') 
df_convokit = df_convokit.drop(columns = ['comment','review'])
df_convokit = df_convokit[df_convokit['text']!='']
df_convokit.to_csv('./data/submissions/df_convokit.csv', index = False)
