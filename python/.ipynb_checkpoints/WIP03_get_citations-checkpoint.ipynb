# %%
import openreview
import pandas as pd
import datetime as date
import tqdm
import json
import ast
import itertools
import matplotlib.pyplot as plt
import requests, json
client = openreview.Client(baseurl='https://api.openreview.net')

# %%
df_author_profiles = pd.read_csv('../data/authors/df_author_profiles.csv')

# %%
def get_openAlex_json(str_first_name = 'raymond',str_middle_name = '',str_last_name = 'zhang'):
    search = "https://api.openalex.org/authors?filter=display_name.search:" + str_first_name + "%20" + str_middle_name + "%20" + str_last_name + "&page=1&per-page=200"
    response = requests.get(search)
    res = json.loads(response.text)
    return res

# %%
lst_author_names_dict = df_author_profiles['names'].tolist()

lst_author_names_dict = [ast.literal_eval(l) for l in lst_author_names_dict]

lst_one_name_author = [l[0] for l in lst_author_names_dict if len(l) == 1 ]

lst_multi_name_author = [l for l in lst_author_names_dict if len(l) != 1 ]
    
lst_one_name_author

#type(lst_author_names_dict[0][0])
# Out:
# [{'first': 'Liu', 'middle': '', 'last': 'Yang', 'username': '~Liu_Yang1'},
#  {'middle': '',
#   'last': 'Cheng',
#   'first': 'MiaoMiao',
#   'username': '~MiaoMiao_Cheng1'},
#  {'middle': '',
#   'first': 'Abhinandan',
#   'last': 'Krishnan',
#   'username': '~Abhinandan_Krishnan1'},
#  {'middle': '',
#   'first': 'Alessandro',
#   'last': 'Magnani',
#   'username': '~Alessandro_Magnani1'},
#  {'middle': '',
#   'first': 'Bastian',
#   'last': 'Bischoff',
#   'username': '~Bastian_Bischoff1'},
#  {'middle': '',
#   'first': 'Francis',
#   'last': 'wyffels',
#   'username': '~Francis_wyffels1'},
#  {'first': 'Naveen',
#   'middle': '',
#   'last': 'Ramakrishnan',
#   'username': '~Naveen_Ramakrishnan1'},
#  {'middle': '',
#   'first': 'Nikolaus',
#   'last': 'Kriegeskorte',
#   'username': '~Nikolaus_Kriegeskorte1'},
#  {'first': 'Walter',
#   'middle': 'F.',
#   'last': 'Stewart',
#   'username': '~Walter_F._Stewart1'},
#  {'preferred': True,
#   'middle': 'Sanjiv',
# ...

# %%
out = []
for dict_author_name in tqdm.tqdm(lst_one_name_author):
    dict_input_row = {}
    dict_input_row['name'] = dict_author_name['first'] + ' ' + dict_author_name['middle'] + ' ' + dict_author_name['last']
    dict_input_row['json'] = get_openAlex_json(dict_author_name['first'],dict_author_name['middle'],dict_author_name['last'])
    out.append(dict_input_row)
    
df_out = pd.DataFrame(out)

# %%
df_out
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
res
# Out:
# {'meta': {'count': 30, 'db_response_time_ms': 35, 'page': 1, 'per_page': 200},
#  'results': [{'id': 'https://openalex.org/A2486499053',
#    'orcid': None,
#    'display_name': 'Raymond Zhang',
#    'display_name_alternatives': [],
#    'relevance_score': 542.55994,
#    'works_count': 11,
#    'cited_by_count': 179,
#    'ids': {'openalex': 'https://openalex.org/A2486499053',
#     'mag': '2486499053'},
#    'last_known_institution': None,
#    'x_concepts': [{'id': 'https://openalex.org/C41008148',
#      'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#      'display_name': 'Computer science',
#      'level': 0,
#      'score': 100.0},
#     {'id': 'https://openalex.org/C31258907',
#      'wikidata': 'https://www.wikidata.org/wiki/Q1301371',
#      'display_name': 'Computer network',
#      'level': 1,
#      'score': 90.9},
#     {'id': 'https://openalex.org/C76155785',
#      'wikidata': 'https://www.wikidata.org/wiki/Q418',
#      'display_name': 'Telecommunications',
# ...
