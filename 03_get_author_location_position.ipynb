# %%
#I want to put this in the get get_author_by_email script later

import openreview
import pandas as pd
import datetime as date
import tqdm
import json
from email2country import email2country,email2institution_country
import matplotlib.pyplot as plt
import ast
client = openreview.Client(baseurl='https://api.openreview.net')

# %%
df_author_info = pd.read_csv('./data/authors/df_author_profiles.csv')

try:
    df_author_info = df_author_info.drop(columns=['Unnamed: 0'])
except:
    pass
df_author_info.history[300]
# Out:
# "[{'position': 'Researcher', 'start': 2021, 'end': None, 'institution': {'domain': 'microsoft.com', 'name': 'Microsoft'}}, {'position': 'PhD student', 'start': 2015, 'end': 2021, 'institution': {'name': 'Johns Hopkins University', 'domain': 'jhu.edu'}}, {'position': 'Undergrad student', 'start': 2011, 'end': 2015, 'institution': {'name': 'University of California Berkeley', 'domain': 'berkeley.edu'}}]"

# %%
#this is gathering all the emails
update = 0
institution_dic ={}

if update ==1:
    for domain in tqdm.tqdm(list(set(df_author_info['email'].apply(lambda x: x.split('@')[1]).tolist()))):
        if domain in institution_dic.keys():
            pass
        else:
            try:
                institution_dic[domain] = client.get_institution(domain)
            except:
                institution_dic[domain] = {'country':domain,'institution':domain}
                
    with open('./data/authors/institution_dic.json', 'w') as fp:
        json.dump(institution_dic, fp)
else:
    institution_dic = json.load(open('./data/authors/institution_dic.json'))

institution_dic
# Out:
# {'iwr.uni-heidelberg.de': {'parent': 'uni-heidelberg.de',
#   'shortname': '',
#   'fullname': 'Heidelberg University',
#   'id': 'iwr.uni-heidelberg.de'},
#  'cs.uni.wroc.pl': {'country': 'cs.uni.wroc.pl',
#   'institution': 'cs.uni.wroc.pl'},
#  'sam.math.ethz.ch': {'country': 'sam.math.ethz.ch',
#   'institution': 'sam.math.ethz.ch'},
#  'ustc.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Science and Technology of China',
#   'id': 'ustc.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.ustc.edu.cn/']},
#  'post.pl': {'country': 'post.pl', 'institution': 'post.pl'},
#  'huan-zhang.com': {'country': 'huan-zhang.com',
#   'institution': 'huan-zhang.com'},
#  'thalesgroup.com': {'country': 'thalesgroup.com',
#   'institution': 'thalesgroup.com'},
#  'ncat.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'North Carolina A&T State University',
#   'id': 'ncat.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ncat.edu/']},
#  'cs.washington.edu': {'parent': 'washington.edu',
#   'shortname': 'CS',
#   'fullname': 'Department of Computer Science',
#   'id': 'cs.washington.edu'},
#  'hlt.utdallas.edu': {'country': 'hlt.utdallas.edu',
#   'institution': 'hlt.utdallas.edu'},
#  'alumni.colostate.edu': {'country': 'alumni.colostate.edu',
#   'institution': 'alumni.colostate.edu'},
#  'put.poznan.pl': {'parent': '',
#   'shortname': '',
#   'fullname': 'Technical University of Poznan',
#   'id': 'put.poznan.pl',
#   'country': 'Poland',
#   'alphaTwoCode': 'PL',
#   'webPages': ['http://www.put.poznan.pl/']},
#  'xtract.ai': {'country': 'xtract.ai', 'institution': 'xtract.ai'},
#  'autodesk.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Autodesk',
#   'id': 'autodesk.com'},
#  'agh.edu.pl': {'parent': '',
#   'shortname': '',
#   'fullname': 'AGH University of Science and Technology',
#   'id': 'agh.edu.pl',
#   'country': 'Poland',
#   'alphaTwoCode': 'PL',
#   'webPages': ['http://www.agh.edu.pl/']},
#  'ttic.edu': {'parent': None,
#   'shortname': '',
#   'fullname': 'Toyota Technological Institute at Chicago',
#   'id': 'ttic.edu'},
#  'biu.ac.il': {'parent': '',
#   'shortname': '',
#   'fullname': 'Bar-Ilan University',
#   'id': 'biu.ac.il',
#   'country': 'Israel',
#   'alphaTwoCode': 'IL',
#   'webPages': ['http://www.biu.ac.il/']},
#  'outlook.com': {'country': 'outlook.com', 'institution': 'outlook.com'},
#  'intel.com': {'parent': None,
#   'shortname': 'Intel',
#   'fullname': 'Intel',
#   'id': 'intel.com'},
#  'harmdevries.com': {'country': 'harmdevries.com',
#   'institution': 'harmdevries.com'},
#  'math.ubc.ca': {'country': 'math.ubc.ca', 'institution': 'math.ubc.ca'},
#  'snap.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Snap Inc.',
#   'id': 'snap.com'},
#  'id.uff.br': {'country': 'id.uff.br', 'institution': 'id.uff.br'},
#  'cs.rutgers.edu': {'parent': 'rutgers.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.rutgers.edu'},
#  'near.ai': {'parent': None,
#   'shortname': '',
#   'fullname': 'NEAR',
#   'id': 'near.ai'},
#  'snapchat.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Snap Inc.',
#   'id': 'snapchat.com'},
#  'cs.uni-freiburg.de': {'parent': 'uni-freiburg.de',
#   'shortname': '',
#   'fullname': 'University of Freiburg',
#   'id': 'cs.uni-freiburg.de'},
#  'eecs.harvard.edu': {'parent': 'seas.harvard.edu',
#   'shortname': '',
#   'fullname': 'Computer Science',
#   'id': 'eecs.harvard.edu'},
#  'lanada.kaist.ac.kr': {'country': 'lanada.kaist.ac.kr',
#   'institution': 'lanada.kaist.ac.kr'},
#  'navercorp.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'NAVER',
#   'id': 'navercorp.com'},
#  'centrica.com': {'country': 'centrica.com', 'institution': 'centrica.com'},
#  'nih.gov': {'country': 'nih.gov', 'institution': 'nih.gov'},
#  'us.panasonic.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Panasonic',
#   'id': 'us.panasonic.com'},
#  'mllab.snu.ac.kr': {'country': 'mllab.snu.ac.kr',
#   'institution': 'mllab.snu.ac.kr'},
#  'sutterhealth.org': {'country': 'sutterhealth.org',
#   'institution': 'sutterhealth.org'},
#  'cs.jhu.edu': {'parent': 'engineering.jhu.edu',
#   'shortname': 'CS',
#   'fullname': 'Department of Computer Science',
#   'id': 'cs.jhu.edu'},
#  'cs.hku.hk': {'parent': 'hku.hk',
#   'shortname': '',
#   'fullname': 'the University of Hong Kong',
#   'id': 'cs.hku.hk'},
#  'layer6.ai': {'country': 'layer6.ai', 'institution': 'layer6.ai'},
#  'mail.ncku.edu.tw': {'country': 'mail.ncku.edu.tw',
#   'institution': 'mail.ncku.edu.tw'},
#  'ohio.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ohio University',
#   'id': 'ohio.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ohio.edu/']},
#  'pstat.ucsb.edu': {'country': 'pstat.ucsb.edu',
#   'institution': 'pstat.ucsb.edu'},
#  'dase.ecnu.edu.cn': {'country': 'dase.ecnu.edu.cn',
#   'institution': 'dase.ecnu.edu.cn'},
#  'ece.ubc.ca': {'country': 'ece.ubc.ca', 'institution': 'ece.ubc.ca'},
#  'maillard.it': {'country': 'maillard.it', 'institution': 'maillard.it'},
#  'tunnel.tech': {'country': 'tunnel.tech', 'institution': 'tunnel.tech'},
#  'uam.es': {'parent': '',
#   'shortname': '',
#   'fullname': 'Universidad Autónoma de Madrid',
#   'id': 'uam.es',
#   'country': 'Spain',
#   'alphaTwoCode': 'ES',
#   'webPages': ['http://www.uam.es/']},
#  'rice.edu': {'parent': '',
#   'shortname': 'Rice',
#   'fullname': 'Rice University',
#   'id': 'rice.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.rice.edu/']},
#  'soton.ac.uk': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Southampton',
#   'id': 'soton.ac.uk',
#   'country': 'United Kingdom',
#   'alphaTwoCode': 'GB',
#   'webPages': ['http://www.southampton.ac.uk/']},
#  'egr.msu.edu': {'country': 'egr.msu.edu', 'institution': 'egr.msu.edu'},
#  'gapp.nthu.edu.tw': {'country': 'gapp.nthu.edu.tw',
#   'institution': 'gapp.nthu.edu.tw'},
#  'fudan.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Fudan University',
#   'id': 'fudan.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.fudan.edu.cn/']},
#  'in.tum.de': {'parent': 'tum.de',
#   'shortname': '',
#   'fullname': 'Department of Informatics',
#   'id': 'in.tum.de'},
#  'rwth-aachen.de': {'parent': '',
#   'shortname': '',
#   'fullname': 'Rheinisch Westfälische Technische Hochschule Aachen',
#   'id': 'rwth-aachen.de',
#   'country': 'Germany',
#   'alphaTwoCode': 'DE',
#   'webPages': ['http://www.rwth-aachen.de/']},
#  'fau.de': {'country': 'fau.de', 'institution': 'fau.de'},
#  'irit.fr': {'parent': None, 'shortname': '', 'fullname': '', 'id': 'irit.fr'},
#  'berkeley.edu': {'parent': '',
#   'shortname': 'UC Berkeley',
#   'fullname': 'University of California, Berkeley',
#   'id': 'berkeley.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.berkeley.edu/']},
#  'allenai.org': {'parent': None,
#   'shortname': 'AI2',
#   'fullname': 'Allen Institute for Artificial Intelligence',
#   'id': 'allenai.org'},
#  'il.ibm.com': {'country': 'il.ibm.com', 'institution': 'il.ibm.com'},
#  'cornell.edu': {'parent': '',
#   'shortname': 'Cornell',
#   'fullname': 'Cornell University',
#   'id': 'cornell.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.cornell.edu/']},
#  'osaro.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Osaro Inc.',
#   'id': 'osaro.com'},
#  'bi.snu.ac.kr': {'country': 'bi.snu.ac.kr', 'institution': 'bi.snu.ac.kr'},
#  'illinois.edu.edu': {'country': 'illinois.edu.edu',
#   'institution': 'illinois.edu.edu'},
#  'mails.ucas.ac.cn': {'country': 'mails.ucas.ac.cn',
#   'institution': 'mails.ucas.ac.cn'},
#  'bcm.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Baylor College of Medicine',
#   'id': 'bcm.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.bcm.edu/']},
#  'renault.com': {'country': 'renault.com', 'institution': 'renault.com'},
#  'asml.com': {'country': 'asml.com', 'institution': 'asml.com'},
#  'siat.ac.cn': {'parent': 'ac.cn',
#   'shortname': '',
#   'fullname': 'Shenzhen Institutes of Advanced Technology, Chinese Academy of Sciences',
#   'id': 'siat.ac.cn'},
#  'borealisai.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Borealis AI',
#   'id': 'borealisai.com'},
#  'corp.netease.com': {'country': 'corp.netease.com',
#   'institution': 'corp.netease.com'},
#  'robot-learning.de': {'country': 'robot-learning.de',
#   'institution': 'robot-learning.de'},
#  'unibas.ch': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Basel',
#   'id': 'unibas.ch',
#   'country': 'Switzerland',
#   'alphaTwoCode': 'CH',
#   'webPages': ['http://www.unibas.ch/']},
#  'uwo.ca': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Western Ontario',
#   'id': 'uwo.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.uwo.ca/']},
#  'tusimple.ai': {'country': 'tusimple.ai', 'institution': 'tusimple.ai'},
#  'edu.k.u-tokyo.ac.jp': {'country': 'edu.k.u-tokyo.ac.jp',
#   'institution': 'edu.k.u-tokyo.ac.jp'},
#  'univ-lille.fr': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'univ-lille.fr'},
#  'gmail.com': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'gmail.com'},
#  'fredhutch.org': {'parent': None,
#   'shortname': '',
#   'fullname': 'Fred Hutchinson Cancer Research Center',
#   'id': 'fredhutch.org'},
#  'cern.ch': {'parent': None,
#   'shortname': '',
#   'fullname': 'CERN',
#   'id': 'cern.ch'},
#  'lip6.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'LIP6',
#   'id': 'lip6.fr'},
#  'seg.nju.edu.cn': {'country': 'seg.nju.edu.cn',
#   'institution': 'seg.nju.edu.cn'},
#  'stud.tu-darmstadt.de': {'country': 'stud.tu-darmstadt.de',
#   'institution': 'stud.tu-darmstadt.de'},
#  'hest.ethz.ch': {'country': 'hest.ethz.ch', 'institution': 'hest.ethz.ch'},
#  'cc.gatech.edu': {'parent': 'gatech.edu',
#   'shortname': '',
#   'fullname': 'College of Computing',
#   'id': 'cc.gatech.edu'},
#  'ouc.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ocean University of China',
#   'id': 'ouc.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.ouc.edu.cn/']},
#  'deakin.edu.au': {'parent': '',
#   'shortname': '',
#   'fullname': 'Deakin University',
#   'id': 'deakin.edu.au',
#   'country': 'Australia',
#   'alphaTwoCode': 'AU',
#   'webPages': ['http://www.deakin.edu.au/']},
#  'dauphine.eu': {'country': 'dauphine.eu', 'institution': 'dauphine.eu'},
#  'ugent.be': {'parent': '',
#   'shortname': '',
#   'fullname': 'Universiteit Gent',
#   'id': 'ugent.be',
#   'country': 'Belgium',
#   'alphaTwoCode': 'BE',
#   'webPages': ['https://www.ugent.be/', 'http://www.rug.ac.be/']},
#  'scut.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'South China University of Technology',
#   'id': 'scut.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.scut.edu.cn/']},
#  'cs.sfu.ca': {'parent': 'sfu.ca',
#   'shortname': '',
#   'fullname': 'Computing Science',
#   'id': 'cs.sfu.ca'},
#  'unice.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Université de Nice-Sophia Antipolis',
#   'id': 'unice.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.unice.fr/']},
#  'njupt.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Nanjing University of Posts and Telecommunications',
#   'id': 'njupt.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.njupt.edu.cn/']},
#  'g.ecc.u-tokyo.ac.jp': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'g.ecc.u-tokyo.ac.jp'},
#  'hse.ru': {'parent': '',
#   'shortname': '',
#   'fullname': 'Higher School of Economics',
#   'id': 'hse.ru',
#   'country': 'Russian Federation',
#   'alphaTwoCode': 'RU',
#   'webPages': ['http://www.hse.ru/']},
#  'bii.a-star.edu.sg': {'country': 'bii.a-star.edu.sg',
#   'institution': 'bii.a-star.edu.sg'},
#  'sentient.ai': {'parent': None,
#   'shortname': '',
#   'fullname': 'Sentient Technologies, Inc.',
#   'id': 'sentient.ai'},
#  'di.ku.dk': {'country': 'di.ku.dk', 'institution': 'di.ku.dk'},
#  'fudan.edu': {'parent': None,
#   'shortname': '',
#   'fullname': 'Fudan University',
#   'id': 'fudan.edu'},
#  'princeton.edu': {'parent': '',
#   'shortname': 'Princeton',
#   'fullname': 'Princeton University',
#   'id': 'princeton.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.princeton.edu/']},
#  'usherbrooke.ca': {'parent': None,
#   'shortname': '',
#   'fullname': 'Université de Sherbrooke',
#   'id': 'usherbrooke.ca'},
#  'petuum.com': {'country': 'petuum.com', 'institution': 'petuum.com'},
#  'gendarmerie.interieur.gouv.fr': {'country': 'gendarmerie.interieur.gouv.fr',
#   'institution': 'gendarmerie.interieur.gouv.fr'},
#  'univ-avignon.fr': {'parent': '',
#   'shortname': '',
#   'fullname': "Université d'Avignon",
#   'id': 'univ-avignon.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.univ-avignon.fr/']},
#  'email.wm.edu': {'country': 'email.wm.edu', 'institution': 'email.wm.edu'},
#  'tid.es': {'country': 'tid.es', 'institution': 'tid.es'},
#  'tu-berlin.de': {'parent': '',
#   'shortname': '',
#   'fullname': 'Technische Universität Berlin',
#   'id': 'tu-berlin.de',
#   'country': 'Germany',
#   'alphaTwoCode': 'DE',
#   'webPages': ['http://www.tu-berlin.de/']},
#  'sdsc.ethz.ch': {'country': 'sdsc.ethz.ch', 'institution': 'sdsc.ethz.ch'},
#  'cmu.edu': {'parent': '',
#   'shortname': 'CMU',
#   'fullname': 'Carnegie Mellon University',
#   'id': 'cmu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.cmu.edu/']},
#  'dwango.co.jp': {'country': 'dwango.co.jp', 'institution': 'dwango.co.jp'},
#  'cripac.ia.ac.cn': {'country': 'cripac.ia.ac.cn',
#   'institution': 'cripac.ia.ac.cn'},
#  'lunit.io': {'parent': None,
#   'shortname': '',
#   'fullname': 'Lunit Inc.',
#   'id': 'lunit.io'},
#  'jacobs-university.de': {'parent': '',
#   'shortname': '',
#   'fullname': 'Jacobs University Bremen',
#   'id': 'jacobs-university.de',
#   'country': 'Germany',
#   'alphaTwoCode': 'DE',
#   'webPages': ['http://www.jacobs-university.de/']},
#  'microsoft.com': {'parent': None,
#   'shortname': 'Microsoft',
#   'fullname': 'Microsoft',
#   'id': 'microsoft.com'},
#  'med.cornell.edu': {'parent': 'cornell.edu',
#   'shortname': '',
#   'fullname': 'Weill Cornell Medicine',
#   'id': 'med.cornell.edu'},
#  'socsim.org': {'country': 'socsim.org', 'institution': 'socsim.org'},
#  'adobe.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Adobe Systems',
#   'id': 'adobe.com'},
#  'mail.rit.edu': {'country': 'mail.rit.edu', 'institution': 'mail.rit.edu'},
#  'limsi.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'LIMSI-CNRS / Université Paris-Sud',
#   'id': 'limsi.fr'},
#  'ualberta.ca': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Alberta',
#   'id': 'ualberta.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.ualberta.ca/']},
#  'aist.go.jp': {'parent': 'go.jp',
#   'shortname': '',
#   'fullname': 'AIST',
#   'id': 'aist.go.jp'},
#  'uni-siegen.de': {'parent': '',
#   'shortname': '',
#   'fullname': 'Universität Siegen',
#   'id': 'uni-siegen.de',
#   'country': 'Germany',
#   'alphaTwoCode': 'DE',
#   'webPages': ['http://www.uni-siegen.de/']},
#  'encs.concordia.ca': {'country': 'encs.concordia.ca',
#   'institution': 'encs.concordia.ca'},
#  'meinertz.org': {'country': 'meinertz.org', 'institution': 'meinertz.org'},
#  'unh.edu': {'parent': '',
#   'shortname': 'UNH',
#   'fullname': 'University of New Hampshire, Durham',
#   'id': 'unh.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.unh.edu/']},
#  'centralesupelec.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'CentraleSupelec',
#   'id': 'centralesupelec.fr'},
#  'ens-rennes.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'Ecole Normale Superieure de Rennes',
#   'id': 'ens-rennes.fr'},
#  'tuebingen.mpg.de': {'parent': 'mpg.de',
#   'shortname': '',
#   'fullname': 'Max Planck Institute for Intelligent Systems',
#   'id': 'tuebingen.mpg.de'},
#  'epfl.ch': {'parent': '',
#   'shortname': 'EPFL',
#   'fullname': 'EPFL - EPF Lausanne',
#   'id': 'epfl.ch',
#   'country': 'Switzerland',
#   'alphaTwoCode': 'CH',
#   'webPages': ['http://www.epfl.ch/', 'http://www.epfl.edu/']},
#  'enpc.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ecole Nationale des Ponts et Chausees',
#   'id': 'enpc.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.enpc.fr/']},
#  'iitkgp.ac.in': {'parent': 'ac.in',
#   'shortname': '',
#   'fullname': 'Indian Institute of Technology Kharagpur',
#   'id': 'iitkgp.ac.in'},
#  'target.com': {'country': 'target.com', 'institution': 'target.com'},
#  'mcgill.ca': {'parent': '',
#   'shortname': 'McGill',
#   'fullname': 'McGill University',
#   'id': 'mcgill.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.mcgill.ca/']},
#  'ict.ac.cn': {'parent': 'ac.cn',
#   'shortname': '',
#   'fullname': '',
#   'id': 'ict.ac.cn'},
#  'dsp.snu.ac.kr': {'country': 'dsp.snu.ac.kr', 'institution': 'dsp.snu.ac.kr'},
#  'ucla.edu': {'parent': '',
#   'shortname': 'UCLA',
#   'fullname': 'University of California, Los Angeles',
#   'id': 'ucla.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ucla.edu/']},
#  'univ-amu.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'Aix Marseille Univ',
#   'id': 'univ-amu.fr'},
#  'le-roux.name': {'country': 'le-roux.name', 'institution': 'le-roux.name'},
#  'bu.edu': {'parent': 'bu.edu',
#   'shortname': '',
#   'fullname': 'Boston University',
#   'id': 'bu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.bu.edu/']},
#  'msu.edu': {'parent': '',
#   'shortname': 'Michigan State',
#   'fullname': 'Michigan State University',
#   'id': 'msu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.msu.edu/']},
#  'oxford-man.ox.ac.uk': {'country': 'oxford-man.ox.ac.uk',
#   'institution': 'oxford-man.ox.ac.uk'},
#  'rubisch.net': {'country': 'rubisch.net', 'institution': 'rubisch.net'},
#  'hertford.ox.ac.uk': {'country': 'hertford.ox.ac.uk',
#   'institution': 'hertford.ox.ac.uk'},
#  'ucsb.edu': {'parent': '',
#   'shortname': 'UCSB',
#   'fullname': 'University of California, Santa Barbara',
#   'id': 'ucsb.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ucsb.edu/']},
#  'ece.tufts.edu': {'country': 'ece.tufts.edu', 'institution': 'ece.tufts.edu'},
#  'louiskirsch.com': {'country': 'louiskirsch.com',
#   'institution': 'louiskirsch.com'},
#  'yandex.ru': {'parent': None,
#   'shortname': '',
#   'fullname': 'Yandex',
#   'id': 'yandex.ru'},
#  'technicolor.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Technicolor',
#   'id': 'technicolor.com'},
#  'sas.upenn.edu': {'country': 'sas.upenn.edu', 'institution': 'sas.upenn.edu'},
#  'pku.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Peking University',
#   'id': 'pku.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.pku.edu.cn/']},
#  'iitk.ac.in': {'parent': 'ac.in',
#   'shortname': '',
#   'fullname': 'Indian Institute of Technology, Kanpur',
#   'id': 'iitk.ac.in',
#   'country': 'India',
#   'alphaTwoCode': 'IN',
#   'webPages': ['http://www.iitk.ac.in/']},
#  'nts.ricoh.co.jp': {'country': 'nts.ricoh.co.jp',
#   'institution': 'nts.ricoh.co.jp'},
#  'gess.ethz.ch': {'country': 'gess.ethz.ch', 'institution': 'gess.ethz.ch'},
#  'math.psu.edu': {'country': 'math.psu.edu', 'institution': 'math.psu.edu'},
#  'ece.pku.edu.cn': {'country': 'ece.pku.edu.cn',
#   'institution': 'ece.pku.edu.cn'},
#  'ti.rwth-aachen.de': {'country': 'ti.rwth-aachen.de',
#   'institution': 'ti.rwth-aachen.de'},
#  'mail.usf.edu': {'parent': 'usf.edu',
#   'shortname': '',
#   'fullname': 'University of South Florida',
#   'id': 'mail.usf.edu'},
#  'byu.edu': {'parent': '',
#   'shortname': 'BYU',
#   'fullname': 'Brigham Young University',
#   'id': 'byu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.byu.edu/']},
#  'deephow.com': {'country': 'deephow.com', 'institution': 'deephow.com'},
#  'hotmail.fr': {'country': 'hotmail.fr', 'institution': 'hotmail.fr'},
#  'iitb.ac.in': {'parent': 'ac.in',
#   'shortname': '',
#   'fullname': 'Indian Institute of Technology, Bombay',
#   'id': 'iitb.ac.in',
#   'country': 'India',
#   'alphaTwoCode': 'IN',
#   'webPages': ['http://www.iitb.ac.in/']},
#  'owkin.com': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'owkin.com'},
#  'polytechnique.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'École Polytechnique',
#   'id': 'polytechnique.edu',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.polytechnique.fr/',
#    'https://www.polytechnique.edu/']},
#  'york.ac.uk': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of York',
#   'id': 'york.ac.uk',
#   'country': 'United Kingdom',
#   'alphaTwoCode': 'GB',
#   'webPages': ['http://www.york.ac.uk/']},
#  'nygenome.org': {'country': 'nygenome.org', 'institution': 'nygenome.org'},
#  'ece.wisc.edu': {'country': 'ece.wisc.edu', 'institution': 'ece.wisc.edu'},
#  'uea.ac.uk': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of East Anglia',
#   'id': 'uea.ac.uk',
#   'country': 'United Kingdom',
#   'alphaTwoCode': 'GB',
#   'webPages': ['http://www.uea.ac.uk/']},
#  'imagia.com': {'country': 'imagia.com', 'institution': 'imagia.com'},
#  'capitalone.com': {'country': 'capitalone.com',
#   'institution': 'capitalone.com'},
#  'me.berkeley.edu': {'country': 'me.berkeley.edu',
#   'institution': 'me.berkeley.edu'},
#  'isr.ist.utl.pt': {'country': 'isr.ist.utl.pt',
#   'institution': 'isr.ist.utl.pt'},
#  'uiuc.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Illinois at Urbana-Champaign',
#   'id': 'uiuc.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.illinois.edu/']},
#  'jp.ricoh.com': {'country': 'jp.ricoh.com', 'institution': 'jp.ricoh.com'},
#  'cs.uni-bonn.de': {'parent': 'uni-bonn.de',
#   'shortname': '',
#   'fullname': 'Rheinische Friedrich-Wilhelms-Universität Bonn',
#   'id': 'cs.uni-bonn.de'},
#  'uky.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Kentucky',
#   'id': 'uky.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.uky.edu/']},
#  'narr.jp': {'country': 'narr.jp', 'institution': 'narr.jp'},
#  'foster.net': {'country': 'foster.net', 'institution': 'foster.net'},
#  'iiit.ac.in': {'parent': 'ac.in',
#   'shortname': '',
#   'fullname': 'International Institute of Information Technology Hyderabad',
#   'id': 'iiit.ac.in'},
#  'cs.ucsd.edu': {'parent': 'ucsd.edu',
#   'shortname': '',
#   'fullname': 'UC San Diego',
#   'id': 'cs.ucsd.edu'},
#  'walmartlabs.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Walmart Labs',
#   'id': 'walmartlabs.com'},
#  'ci.i.u-tokyo.ac.jp': {'country': 'ci.i.u-tokyo.ac.jp',
#   'institution': 'ci.i.u-tokyo.ac.jp'},
#  'utstat.toronto.edu': {'country': 'utstat.toronto.edu',
#   'institution': 'utstat.toronto.edu'},
#  'iisc.ac.in': {'parent': 'ac.in',
#   'shortname': '',
#   'fullname': 'Indian Institute of Science',
#   'id': 'iisc.ac.in'},
#  'binghamton.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'State University of New York at Binghamton',
#   'id': 'binghamton.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.binghamton.edu/']},
#  'iss.uni-stuttgart.de': {'country': 'iss.uni-stuttgart.de',
#   'institution': 'iss.uni-stuttgart.de'},
#  'ee.iitm.ac.in': {'parent': 'iitm.ac.in',
#   'shortname': '',
#   'fullname': 'Indian Institute of Technology Madras',
#   'id': 'ee.iitm.ac.in'},
#  'csie.ntu.edu.tw': {'parent': 'ntu.edu.tw',
#   'shortname': 'CSIE',
#   'fullname': 'Department of computer science and informational engineering',
#   'id': 'csie.ntu.edu.tw'},
#  'isical.ac.in': {'parent': 'ac.in',
#   'shortname': '',
#   'fullname': 'Indian Statistical Institute',
#   'id': 'isical.ac.in',
#   'country': 'India',
#   'alphaTwoCode': 'IN',
#   'webPages': ['http://www.isical.ac.in/']},
#  'nbicc.com': {'country': 'nbicc.com', 'institution': 'nbicc.com'},
#  'cs.ox.ac.uk': {'parent': 'oxford.ac.uk',
#   'shortname': 'CS',
#   'fullname': 'Department of Computer Science',
#   'id': 'cs.ox.ac.uk'},
#  'socher.org': {'country': 'socher.org', 'institution': 'socher.org'},
#  'inf.ethz.ch': {'parent': 'ethz.ch',
#   'shortname': 'CS',
#   'fullname': 'Department of Computer Science',
#   'id': 'inf.ethz.ch'},
#  'cs.ucr.edu': {'parent': 'ucr.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.ucr.edu'},
#  'it.uu.se': {'country': 'it.uu.se', 'institution': 'it.uu.se'},
#  'hotmail.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Freelance',
#   'id': 'hotmail.com'},
#  'mitre.org': {'country': 'mitre.org', 'institution': 'mitre.org'},
#  'seas.harvard.edu': {'parent': 'harvard.edu',
#   'shortname': 'SEAS',
#   'fullname': 'School of Engineering and Applied Sciences',
#   'id': 'seas.harvard.edu'},
#  'phystech.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Moscow Institute of Physics and Technology',
#   'id': 'phystech.edu',
#   'country': 'Russian Federation',
#   'alphaTwoCode': 'RU',
#   'webPages': ['http://www.mipt.ru/', 'http://www.phystech.edu/']},
#  'basistech.com': {'country': 'basistech.com', 'institution': 'basistech.com'},
#  'washington.edu': {'parent': '',
#   'shortname': 'Washington',
#   'fullname': 'University of Washington',
#   'id': 'washington.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.washington.edu/']},
#  'icl.utk.edu': {'country': 'icl.utk.edu', 'institution': 'icl.utk.edu'},
#  'dst.defence.gov.au': {'country': 'dst.defence.gov.au',
#   'institution': 'dst.defence.gov.au'},
#  'g.ucla.edu': {'country': 'g.ucla.edu', 'institution': 'g.ucla.edu'},
#  'ece.ucsb.edu': {'country': 'ece.ucsb.edu', 'institution': 'ece.ucsb.edu'},
#  'clemson.edu': {'parent': '',
#   'shortname': 'Clemson',
#   'fullname': 'Clemson University',
#   'id': 'clemson.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.clemson.edu/']},
#  'cin.ufpe.br': {'parent': 'ufpe.br',
#   'shortname': '',
#   'fullname': 'Universidade Federal de Pernambuco',
#   'id': 'cin.ufpe.br'},
#  'll.mit.edu': {'parent': 'mit.edu',
#   'shortname': '',
#   'fullname': 'MIT Lincoln Laboratory',
#   'id': 'll.mit.edu'},
#  'mst.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Missouri University of Science and Technology',
#   'id': 'mst.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.mst.edu/']},
#  'upmc.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'Computer Science Lab  - Pierre and Marie Curie University, Paris, France',
#   'id': 'upmc.fr'},
#  'ensta.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ecole Nationale Supérieure de Techniques Avancées',
#   'id': 'ensta.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.ensta.fr/']},
#  'virginia.edu': {'parent': '',
#   'shortname': 'Virginia',
#   'fullname': 'University of Virginia, Charlottesville',
#   'id': 'virginia.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.virginia.edu/']},
#  'tri.global': {'parent': None,
#   'shortname': '',
#   'fullname': 'Toyota Research Institute',
#   'id': 'tri.global'},
#  'inesc-id.pt': {'country': 'inesc-id.pt', 'institution': 'inesc-id.pt'},
#  'umail.iu.edu': {'country': 'umail.iu.edu', 'institution': 'umail.iu.edu'},
#  'cs.fit.edu': {'parent': 'fit.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.fit.edu'},
#  'yonatanbisk.com': {'country': 'yonatanbisk.com',
#   'institution': 'yonatanbisk.com'},
#  'mails.tsinghua.edu.cn': {'parent': 'tsinghua.edu.cn',
#   'shortname': '',
#   'fullname': 'Electronic Engineering, Tsinghua University',
#   'id': 'mails.tsinghua.edu.cn'},
#  'victorzhong.com': {'country': 'victorzhong.com',
#   'institution': 'victorzhong.com'},
#  'fas.harvard.edu': {'parent': 'harvard.edu',
#   'shortname': '',
#   'fullname': 'Harvard University',
#   'id': 'fas.harvard.edu'},
#  'qut.edu.au': {'parent': '',
#   'shortname': '',
#   'fullname': 'Queensland University of Technology',
#   'id': 'qut.edu.au',
#   'country': 'Australia',
#   'alphaTwoCode': 'AU',
#   'webPages': ['http://www.qut.edu.au/']},
#  'cs.stir.ac.uk': {'country': 'cs.stir.ac.uk', 'institution': 'cs.stir.ac.uk'},
#  'caiyunapp.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'ColorfulClouds Tech.',
#   'id': 'caiyunapp.com'},
#  'yitu-inc.com': {'country': 'yitu-inc.com', 'institution': 'yitu-inc.com'},
#  'informatik.uni-hamburg.de': {'country': 'informatik.uni-hamburg.de',
#   'institution': 'informatik.uni-hamburg.de'},
#  'bsc.es': {'parent': None,
#   'shortname': '',
#   'fullname': 'Barcelona Supercomputing Center',
#   'id': 'bsc.es'},
#  'cs.stonybrook.edu': {'parent': 'stonybrook.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.stonybrook.edu'},
#  'pkusz.edu.cn': {'country': 'pkusz.edu.cn', 'institution': 'pkusz.edu.cn'},
#  'zi-mannheim.de': {'country': 'zi-mannheim.de',
#   'institution': 'zi-mannheim.de'},
#  'unisi.it': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Siena',
#   'id': 'unisi.it',
#   'country': 'Italy',
#   'alphaTwoCode': 'IT',
#   'webPages': ['http://www.unisi.it/']},
#  'linecorp.com': {'country': 'linecorp.com', 'institution': 'linecorp.com'},
#  'mit.edu': {'parent': '',
#   'shortname': 'MIT',
#   'fullname': 'Massachusetts Institute of Technology',
#   'id': 'mit.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://web.mit.edu/']},
#  'indiana.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Indiana University at Bloomington',
#   'id': 'indiana.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.indiana.edu/']},
#  'arm.com': {'country': 'arm.com', 'institution': 'arm.com'},
#  'htwg-konstanz.de': {'country': 'htwg-konstanz.de',
#   'institution': 'htwg-konstanz.de'},
#  'informatik.uni-freiburg.de': {'parent': 'uni-freiburg.de',
#   'shortname': '',
#   'fullname': 'CS Department, University of Freiburg, Germany',
#   'id': 'informatik.uni-freiburg.de'},
#  'cs.upc.edu': {'country': 'cs.upc.edu', 'institution': 'cs.upc.edu'},
#  'univ-paris-diderot.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'Université Paris Diderot',
#   'id': 'univ-paris-diderot.fr'},
#  'vt.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Virginia Polytechnic Institute and State University',
#   'id': 'vt.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.vt.edu/']},
#  'gmu.edu': {'parent': '',
#   'shortname': 'GMU',
#   'fullname': 'George Mason University',
#   'id': 'gmu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.gmu.edu/']},
#  'gsu.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Georgia State University',
#   'id': 'gsu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.gsu.edu/']},
#  'ist.ac.at': {'parent': '',
#   'shortname': '',
#   'fullname': 'Institute of Science and Technology',
#   'id': 'ist.ac.at',
#   'country': 'Austria',
#   'alphaTwoCode': 'AT',
#   'webPages': ['http://www.ist.ac.at/']},
#  'skoltech.ru': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'skoltech.ru'},
#  'iphy.ac.cn': {'country': 'iphy.ac.cn', 'institution': 'iphy.ac.cn'},
#  'chalmers.se': {'parent': '',
#   'shortname': '',
#   'fullname': 'Chalmers University of Technology',
#   'id': 'chalmers.se',
#   'country': 'Sweden',
#   'alphaTwoCode': 'SE',
#   'webPages': ['http://www.chalmers.se/']},
#  'docomoinnovations.com': {'country': 'docomoinnovations.com',
#   'institution': 'docomoinnovations.com'},
#  'rit.kaist.ac.kr': {'country': 'rit.kaist.ac.kr',
#   'institution': 'rit.kaist.ac.kr'},
#  'live.jp': {'country': 'live.jp', 'institution': 'live.jp'},
#  'eidos.ic.i.u-tokyo.ac.jp': {'country': 'eidos.ic.i.u-tokyo.ac.jp',
#   'institution': 'eidos.ic.i.u-tokyo.ac.jp'},
#  'tongzhang-ml.org': {'country': 'tongzhang-ml.org',
#   'institution': 'tongzhang-ml.org'},
#  'alumni.brown.edu': {'country': 'alumni.brown.edu',
#   'institution': 'alumni.brown.edu'},
#  'louisiana.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Louisiana at Lafeyette',
#   'id': 'louisiana.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.louisiana.edu/']},
#  'jd.com': {'country': 'jd.com', 'institution': 'jd.com'},
#  'eagles.ewu.edu': {'country': 'eagles.ewu.edu',
#   'institution': 'eagles.ewu.edu'},
#  'sys.t.u-tokyo.ac.jp': {'country': 'sys.t.u-tokyo.ac.jp',
#   'institution': 'sys.t.u-tokyo.ac.jp'},
#  '1qbit.com': {'country': '1qbit.com', 'institution': '1qbit.com'},
#  'leapmind.io': {'parent': None,
#   'shortname': '',
#   'fullname': 'Leapmind Inc.',
#   'id': 'leapmind.io'},
#  'zalando.de': {'country': 'zalando.de', 'institution': 'zalando.de'},
#  'hbku.edu.qa': {'country': 'hbku.edu.qa', 'institution': 'hbku.edu.qa'},
#  'dima.unige.it': {'country': 'dima.unige.it', 'institution': 'dima.unige.it'},
#  'imt-atlantique.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'IMT Atlantique',
#   'id': 'imt-atlantique.fr'},
#  'citi.sinica.edu.tw': {'country': 'citi.sinica.edu.tw',
#   'institution': 'citi.sinica.edu.tw'},
#  'mail.neu.edu.cn': {'country': 'mail.neu.edu.cn',
#   'institution': 'mail.neu.edu.cn'},
#  'clarkson.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Clarkson University',
#   'id': 'clarkson.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.clarkson.edu/']},
#  'nicklim.com': {'country': 'nicklim.com', 'institution': 'nicklim.com'},
#  'dfki.de': {'parent': None,
#   'shortname': '',
#   'fullname': 'German Research Center for AI',
#   'id': 'dfki.de'},
#  'iit.it': {'parent': None,
#   'shortname': '',
#   'fullname': 'Università degli Studi di Genova, Istituto Italiano di Tecnologia',
#   'id': 'iit.it'},
#  'eecs.northwestern.edu': {'parent': 'northwestern.edu',
#   'shortname': 'EECS',
#   'fullname': 'Department of Electrical Engineering and Computer Science',
#   'id': 'eecs.northwestern.edu'},
#  'iro.umontreal.ca': {'parent': 'umontreal.ca',
#   'shortname': '',
#   'fullname': 'University of Montreal',
#   'id': 'iro.umontreal.ca'},
#  'lix.polytechnique.fr': {'country': 'lix.polytechnique.fr',
#   'institution': 'lix.polytechnique.fr'},
#  'ulaval.ca': {'parent': '',
#   'shortname': '',
#   'fullname': 'Université Laval',
#   'id': 'ulaval.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.ulaval.ca/']},
#  'lehigh.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Lehigh University',
#   'id': 'lehigh.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.lehigh.edu/']},
#  'ie.cuhk.edu.hk': {'country': 'ie.cuhk.edu.hk',
#   'institution': 'ie.cuhk.edu.hk'},
#  'mail.utoronto.ca': {'country': 'mail.utoronto.ca',
#   'institution': 'mail.utoronto.ca'},
#  'usi.ch': {'parent': '',
#   'shortname': '',
#   'fullname': 'Universita della Svizzera Italiana',
#   'id': 'usi.ch',
#   'country': 'Switzerland',
#   'alphaTwoCode': 'CH',
#   'webPages': ['http://www.usi.ch/']},
#  'cs.umn.edu': {'parent': 'umn.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.umn.edu'},
#  'eee.hku.hk': {'parent': 'hku.hk',
#   'shortname': '',
#   'fullname': '',
#   'id': 'eee.hku.hk'},
#  'alibaba-inc.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Alibaba Group',
#   'id': 'alibaba-inc.com'},
#  'parisdescartes.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'University Paris Descartes',
#   'id': 'parisdescartes.fr'},
#  'taboola.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Taboola',
#   'id': 'taboola.com'},
#  'uj.edu.pl': {'parent': '',
#   'shortname': '',
#   'fullname': 'Jagiellonian University Cracow',
#   'id': 'uj.edu.pl',
#   'country': 'Poland',
#   'alphaTwoCode': 'PL',
#   'webPages': ['http://www.uj.edu.pl/']},
#  'ofai.at': {'parent': None,
#   'shortname': '',
#   'fullname': 'Austrian Research Institute for Artificial Intelligence',
#   'id': 'ofai.at'},
#  'xidian.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': "Xi'an University of Electronic Science and Technology",
#   'id': 'xidian.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.xidian.edu.cn/']},
#  'email.arizona.edu': {'country': 'email.arizona.edu',
#   'institution': 'email.arizona.edu'},
#  'perimeterinstitute.ca': {'country': 'perimeterinstitute.ca',
#   'institution': 'perimeterinstitute.ca'},
#  'mines-paristech.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'Mines ParisTech',
#   'id': 'mines-paristech.fr'},
#  'etud.univ-tln.fr': {'country': 'etud.univ-tln.fr',
#   'institution': 'etud.univ-tln.fr'},
#  'smail.iitm.ac.in': {'country': 'smail.iitm.ac.in',
#   'institution': 'smail.iitm.ac.in'},
#  'vast.uccs.edu': {'country': 'vast.uccs.edu', 'institution': 'vast.uccs.edu'},
#  'uni-graz.at': {'country': 'uni-graz.at', 'institution': 'uni-graz.at'},
#  'mail.xidian.edu.cn': {'country': 'mail.xidian.edu.cn',
#   'institution': 'mail.xidian.edu.cn'},
#  'gipsa-lab.grenoble-inp.fr': {'country': 'gipsa-lab.grenoble-inp.fr',
#   'institution': 'gipsa-lab.grenoble-inp.fr'},
#  'isi.imi.i.u-tokyo.ac.jp': {'country': 'isi.imi.i.u-tokyo.ac.jp',
#   'institution': 'isi.imi.i.u-tokyo.ac.jp'},
#  'aediworks.com': {'country': 'aediworks.com', 'institution': 'aediworks.com'},
#  'austin.utexas.edu': {'country': 'austin.utexas.edu',
#   'institution': 'austin.utexas.edu'},
#  'aifounded.com': {'country': 'aifounded.com', 'institution': 'aifounded.com'},
#  'colostate.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Colorado State University',
#   'id': 'colostate.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.colostate.edu/']},
#  'cogsci.jhu.edu': {'country': 'cogsci.jhu.edu',
#   'institution': 'cogsci.jhu.edu'},
#  'bit.uni-bonn.de': {'country': 'bit.uni-bonn.de',
#   'institution': 'bit.uni-bonn.de'},
#  'vedecom.fr': {'country': 'vedecom.fr', 'institution': 'vedecom.fr'},
#  'orange.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Orange-labs',
#   'id': 'orange.com'},
#  'i.kyoto-u.ac.jp': {'parent': 'kyoto-u.ac.jp',
#   'shortname': '',
#   'fullname': 'Kyoto University',
#   'id': 'i.kyoto-u.ac.jp'},
#  'tecnico.ulisboa.pt': {'parent': None,
#   'shortname': '',
#   'fullname': 'Instituto Superior Técnico',
#   'id': 'tecnico.ulisboa.pt'},
#  'umich.edu': {'parent': '',
#   'shortname': 'Michigan',
#   'fullname': 'University of Michigan - Ann Arbor',
#   'id': 'umich.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.umich.edu/']},
#  'ist.psu.edu': {'parent': 'psu.edu',
#   'shortname': '',
#   'fullname': 'Pennsylvania State University',
#   'id': 'ist.psu.edu'},
#  'eng.cam.ac.uk': {'country': 'eng.cam.ac.uk', 'institution': 'eng.cam.ac.uk'},
#  'wustl.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Washington University, Saint Louis',
#   'id': 'wustl.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.wustl.edu/']},
#  'uber.com': {'parent': None,
#   'shortname': 'Uber',
#   'fullname': 'Uber',
#   'id': 'uber.com'},
#  'us.ibm.com': {'parent': 'ibm.com',
#   'shortname': '',
#   'fullname': 'IBM',
#   'id': 'us.ibm.com'},
#  'mosk.tytlabs.co.jp': {'country': 'mosk.tytlabs.co.jp',
#   'institution': 'mosk.tytlabs.co.jp'},
#  'ic.uff.br': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'ic.uff.br'},
#  'froglabs.ai': {'country': 'froglabs.ai', 'institution': 'froglabs.ai'},
#  'mail.mil': {'country': 'mail.mil', 'institution': 'mail.mil'},
#  'mie.utoronto.ca': {'parent': 'utoronto.ca',
#   'shortname': '',
#   'fullname': 'Department of Mechanical and Industrial Engineering, University of Toronto',
#   'id': 'mie.utoronto.ca'},
#  'duke.edu': {'parent': '',
#   'shortname': 'Duke',
#   'fullname': 'Duke University',
#   'id': 'duke.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.duke.edu/']},
#  'stats.com': {'country': 'stats.com', 'institution': 'stats.com'},
#  'inria.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'INRIA',
#   'id': 'inria.fr'},
#  'cims.nyu.edu': {'parent': 'nyu.edu',
#   'shortname': '',
#   'fullname': 'NYU',
#   'id': 'cims.nyu.edu'},
#  'mssm.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Icahn School of Medicine at Mount Sinai',
#   'id': 'mssm.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://icahn.mssm.edu/']},
#  'jpl.nasa.gov': {'parent': 'nasa.gov',
#   'shortname': '',
#   'fullname': 'Jet Propulsion Laboratory',
#   'id': 'jpl.nasa.gov'},
#  'hao-li.com': {'country': 'hao-li.com', 'institution': 'hao-li.com'},
#  'dsic.upv.es': {'parent': 'upv.es',
#   'shortname': '',
#   'fullname': 'UPV',
#   'id': 'dsic.upv.es'},
#  'ircam.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Institut de Recherche et Coordination Acoustique/Musique',
#   'id': 'ircam.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.ircam.fr/']},
#  'colorado.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Colorado at Boulder',
#   'id': 'colorado.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.colorado.edu/']},
#  'kaist.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Korea Advanced Institute of Science & Technology',
#   'id': 'kaist.edu',
#   'country': 'Korea, Republic of',
#   'alphaTwoCode': 'KR',
#   'webPages': ['http://www.kaist.ac.kr/']},
#  'nict.go.jp': {'parent': 'go.jp',
#   'shortname': '',
#   'fullname': 'National Institute of Information and Communications Technology (NICT)',
#   'id': 'nict.go.jp'},
#  'cn.fujitsu.com': {'country': 'cn.fujitsu.com',
#   'institution': 'cn.fujitsu.com'},
#  'uta.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Texas at Arlington',
#   'id': 'uta.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.uta.edu/']},
#  'psi.toronto.edu': {'country': 'psi.toronto.edu',
#   'institution': 'psi.toronto.edu'},
#  'apple.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Apple',
#   'id': 'apple.com'},
#  'dauphine.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Université Paris-Dauphine (Paris IX)',
#   'id': 'dauphine.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.dauphine.fr/']},
#  'phdis.smu.edu.sg': {'parent': 'smu.edu.sg',
#   'shortname': '',
#   'fullname': 'Singapore Management University',
#   'id': 'phdis.smu.edu.sg'},
#  'ce.yildiz.edu.tr': {'country': 'ce.yildiz.edu.tr',
#   'institution': 'ce.yildiz.edu.tr'},
#  'isr.tecnico.ulisboa.pt': {'country': 'isr.tecnico.ulisboa.pt',
#   'institution': 'isr.tecnico.ulisboa.pt'},
#  'hqu.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Huaqiao University Quanzhuo',
#   'id': 'hqu.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.hqu.edu.cn/']},
#  'purdue.edu': {'parent': '',
#   'shortname': 'Purdue',
#   'fullname': 'Purdue University',
#   'id': 'purdue.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.purdue.edu/']},
#  'nus.edu.sg': {'parent': '',
#   'shortname': '',
#   'fullname': 'National University of Singapore',
#   'id': 'nus.edu.sg',
#   'country': 'Singapore',
#   'alphaTwoCode': 'SG',
#   'webPages': ['http://www.nus.edu/', 'http://www.nus.edu.sg/']},
#  'cse.psu.edu': {'parent': 'psu.edu',
#   'shortname': '',
#   'fullname': 'Pennsylvania State University',
#   'id': 'cse.psu.edu'},
#  'insofe.edu.in': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'insofe.edu.in'},
#  'smola.org': {'country': 'smola.org', 'institution': 'smola.org'},
#  'ivalua.com': {'country': 'ivalua.com', 'institution': 'ivalua.com'},
#  'vision.ee.ethz.ch': {'parent': None,
#   'shortname': '',
#   'fullname': 'ETH Zurich',
#   'id': 'vision.ee.ethz.ch'},
#  'riken.jp': {'parent': None,
#   'shortname': '',
#   'fullname': 'RIKEN',
#   'id': 'riken.jp'},
#  'usc.edu': {'parent': '',
#   'shortname': 'USC',
#   'fullname': 'University of Southern California',
#   'id': 'usc.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.usc.edu/']},
#  'UGent.be': {'country': 'UGent.be', 'institution': 'UGent.be'},
#  'cs.columbia.edu': {'parent': 'columbia.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.columbia.edu'},
#  'eng.ucsd.edu': {'parent': 'ucsd.edu',
#   'shortname': '',
#   'fullname': 'University of California, San Diego',
#   'id': 'eng.ucsd.edu'},
#  'safrangroup.com': {'country': 'safrangroup.com',
#   'institution': 'safrangroup.com'},
#  'cs.hs-fulda.de': {'country': 'cs.hs-fulda.de',
#   'institution': 'cs.hs-fulda.de'},
#  'gaps.ssr.upm.es': {'country': 'gaps.ssr.upm.es',
#   'institution': 'gaps.ssr.upm.es'},
#  'gold.ac.uk': {'parent': '',
#   'shortname': '',
#   'fullname': 'Goldsmiths College, University of London',
#   'id': 'gold.ac.uk',
#   'country': 'United Kingdom',
#   'alphaTwoCode': 'GB',
#   'webPages': ['http://www.gold.ac.uk/']},
#  'rmit.edu.au': {'parent': '',
#   'shortname': '',
#   'fullname': 'Royal Melbourne Institute of Technology',
#   'id': 'rmit.edu.au',
#   'country': 'Australia',
#   'alphaTwoCode': 'AU',
#   'webPages': ['http://www.rmit.edu.au/']},
#  'cml.snu.ac.kr': {'country': 'cml.snu.ac.kr', 'institution': 'cml.snu.ac.kr'},
#  'inceptioniai.org': {'country': 'inceptioniai.org',
#   'institution': 'inceptioniai.org'},
#  'nju.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Nanjing University',
#   'id': 'nju.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.nju.edu.cn/']},
#  'northwestern.edu': {'parent': '',
#   'shortname': 'Northwestern',
#   'fullname': 'Northwestern University',
#   'id': 'northwestern.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.northwestern.edu/']},
#  'ucas.ac.cn': {'parent': '',
#   'shortname': 'UCAS',
#   'fullname': 'University of the Chinese Academy of Sciences',
#   'id': 'ucas.ac.cn',
#   'country': 'China',
#   'webPages': ['http://www.ucas.ac.cn/']},
#  'etu.unige.ch': {'country': 'etu.unige.ch', 'institution': 'etu.unige.ch'},
#  'data61.csiro.au': {'parent': 'csiro.au',
#   'shortname': '',
#   'fullname': '',
#   'id': 'data61.csiro.au'},
#  'imagen.ai': {'country': 'imagen.ai', 'institution': 'imagen.ai'},
#  'eng.ox.ac.uk': {'parent': 'ox.ac.uk',
#   'shortname': '',
#   'fullname': 'University of Oxford',
#   'id': 'eng.ox.ac.uk'},
#  'polito.it': {'parent': '',
#   'shortname': '',
#   'fullname': 'Polytechnic Institute of Turin',
#   'id': 'polito.it',
#   'country': 'Italy',
#   'alphaTwoCode': 'IT',
#   'webPages': ['http://www.polito.it/']},
#  'gatech.edu': {'parent': '',
#   'shortname': 'GATech',
#   'fullname': 'Georgia Institute of Technology',
#   'id': 'gatech.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.gatech.edu/']},
#  'uclouvain.be': {'parent': None,
#   'shortname': '',
#   'fullname': 'UCL',
#   'id': 'uclouvain.be'},
#  'hobot.cc': {'parent': None,
#   'shortname': '',
#   'fullname': 'Horizon Robotics',
#   'id': 'hobot.cc'},
#  'anu.edu.au': {'parent': '',
#   'shortname': '',
#   'fullname': 'Australian National University',
#   'id': 'anu.edu.au',
#   'country': 'Australia',
#   'alphaTwoCode': 'AU',
#   'webPages': ['http://www.anu.edu.au/']},
#  'bethgelab.org': {'parent': None,
#   'shortname': '',
#   'fullname': 'Centre for Integrative Neuroscience, AG Bethge',
#   'id': 'bethgelab.org'},
#  'cwi.nl': {'parent': None,
#   'shortname': '',
#   'fullname': 'Centrum voor Wiskunde en Informatica',
#   'id': 'cwi.nl'},
#  'ntu.edu.tw': {'parent': '',
#   'shortname': 'NTU',
#   'fullname': 'National Taiwan University',
#   'id': 'ntu.edu.tw',
#   'country': 'Taiwan',
#   'alphaTwoCode': 'TW',
#   'webPages': ['http://www.ntu.edu.tw/']},
#  'google.com': {'parent': None,
#   'shortname': 'Google',
#   'fullname': 'Google',
#   'id': 'google.com'},
#  'babylonhealth.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'babylon health',
#   'id': 'babylonhealth.com'},
#  'vision.snu.ac.kr': {'country': 'vision.snu.ac.kr',
#   'institution': 'vision.snu.ac.kr'},
#  'kit.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Karlsruher Institut für Technologie',
#   'id': 'kit.edu',
#   'country': 'Germany',
#   'alphaTwoCode': 'DE',
#   'webPages': ['http://www.kit.edu/']},
#  'ensta-paristech.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'ENSTA ParisTech',
#   'id': 'ensta-paristech.fr'},
#  'idsia.ch': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'idsia.ch'},
#  'postech.ac.kr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Pohang University of Science and Technology',
#   'id': 'postech.ac.kr',
#   'country': 'Korea, Republic of',
#   'alphaTwoCode': 'KR',
#   'webPages': ['http://www.postech.ac.kr/', 'http://www.postech.edu/']},
# ...
#   'country': 'Korea, Republic of',
#   'alphaTwoCode': 'KR',
#   'webPages': ['http://www.handong.edu']},
#  'ncsu.edu': {'parent': '',
#   'shortname': 'NCSU',
#   'fullname': 'North Carolina State University',
#   'id': 'ncsu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ncsu.edu/']},
#  'corp.mail.ru': {'country': 'corp.mail.ru', 'institution': 'corp.mail.ru'},
#  'uchicago.edu': {'parent': '',
#   'shortname': 'Chicago',
#   'fullname': 'University of Chicago',
#   'id': 'uchicago.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.uchicago.edu/']},
#  'cs.uni-saarland.de': {'parent': 'uni-saarland.de',
#   'shortname': '',
#   'fullname': 'Saarland University',
#   'id': 'cs.uni-saarland.de'},
#  'smzy.cc': {'country': 'smzy.cc', 'institution': 'smzy.cc'},
#  'd-itlab.co.jp': {'country': 'd-itlab.co.jp', 'institution': 'd-itlab.co.jp'},
#  'ciencias.ulisboa.pt': {'country': 'ciencias.ulisboa.pt',
#   'institution': 'ciencias.ulisboa.pt'},
#  'aitrics.com': {'country': 'aitrics.com', 'institution': 'aitrics.com'},
#  'hawaii.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Hawaii System',
#   'id': 'hawaii.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.hawaii.edu/']},
#  'cam.ack.uk': {'country': 'cam.ack.uk', 'institution': 'cam.ack.uk'},
#  'mila.quebec': {'country': 'mila.quebec', 'institution': 'mila.quebec'},
#  'ifmlab.org': {'country': 'ifmlab.org', 'institution': 'ifmlab.org'},
#  'queensu.ca': {'parent': '',
#   'shortname': '',
#   'fullname': "Queen's University",
#   'id': 'queensu.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.queensu.ca/']},
#  'snu.ac.kr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Seoul National University',
#   'id': 'snu.ac.kr',
#   'country': 'Korea, Republic of',
#   'alphaTwoCode': 'KR',
#   'webPages': ['http://www.snu.ac.kr/']},
#  'aalto.fi': {'parent': '',
#   'shortname': '',
#   'fullname': 'Aalto University',
#   'id': 'aalto.fi',
#   'country': 'Finland',
#   'alphaTwoCode': 'FI',
#   'webPages': ['https://www.aalto.fi']},
#  'wpi.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Worcester Polytechnic Institute',
#   'id': 'wpi.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.wpi.edu/']},
#  'andrew.cmu.edu': {'parent': 'cmu.edu',
#   'shortname': '',
#   'fullname': 'CMU',
#   'id': 'andrew.cmu.edu'},
#  'u.nus.edu': {'parent': 'nus.edu',
#   'shortname': '',
#   'fullname': 'national university of singaore',
#   'id': 'u.nus.edu'},
#  'math.byu.edu': {'country': 'math.byu.edu', 'institution': 'math.byu.edu'},
#  'bottou.org': {'country': 'bottou.org', 'institution': 'bottou.org'},
#  'gatsby.ucl.ac.uk': {'country': 'gatsby.ucl.ac.uk',
#   'institution': 'gatsby.ucl.ac.uk'},
#  'aueb.gr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Athens University of Economics and Business',
#   'id': 'aueb.gr',
#   'country': 'Greece',
#   'alphaTwoCode': 'GR',
#   'webPages': ['http://www.aueb.gr/']},
#  'mail2.sysu.edu.cn': {'country': 'mail2.sysu.edu.cn',
#   'institution': 'mail2.sysu.edu.cn'},
#  'kcl.ac.uk': {'parent': '',
#   'shortname': '',
#   'fullname': "King's College London, University of London",
#   'id': 'kcl.ac.uk',
#   'country': 'United Kingdom',
#   'alphaTwoCode': 'GB',
#   'webPages': ['http://www.kcl.ac.uk/']},
#  'cea.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'CEA',
#   'id': 'cea.fr'},
#  'xmu.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Xiamen University',
#   'id': 'xmu.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.xmu.edu.cn/']},
#  'bayer.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Bayer Ag',
#   'id': 'bayer.com'},
#  'csulb.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'California State University, Long Beach',
#   'id': 'csulb.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.csulb.edu/']},
#  'mccombs.utexas.edu': {'country': 'mccombs.utexas.edu',
#   'institution': 'mccombs.utexas.edu'},
#  'mrtz.org': {'country': 'mrtz.org', 'institution': 'mrtz.org'},
#  'eecs.wsu.edu': {'parent': 'wsu.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'eecs.wsu.edu'},
#  'cs.utah.edu': {'parent': 'utah.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.utah.edu'},
#  'jhu.edu': {'parent': '',
#   'shortname': 'JHU',
#   'fullname': 'Johns Hopkins University',
#   'id': 'jhu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.jhu.edu/']},
#  'synapse-fr.com': {'country': 'synapse-fr.com',
#   'institution': 'synapse-fr.com'},
#  'telecom-paristech.fr': {'parent': None,
#   'shortname': '',
#   'fullname': 'Télécom ParisTech',
#   'id': 'telecom-paristech.fr'},
#  'ar.sanken.osaka-u.ac.jp': {'country': 'ar.sanken.osaka-u.ac.jp',
#   'institution': 'ar.sanken.osaka-u.ac.jp'},
#  'encoredtech.com': {'country': 'encoredtech.com',
#   'institution': 'encoredtech.com'},
#  'cnbc.cmu.edu': {'country': 'cnbc.cmu.edu', 'institution': 'cnbc.cmu.edu'},
#  'ecs.vuw.ac.nz': {'country': 'ecs.vuw.ac.nz', 'institution': 'ecs.vuw.ac.nz'},
#  'for.ai': {'country': 'for.ai', 'institution': 'for.ai'},
#  'gmx.de': {'country': 'gmx.de', 'institution': 'gmx.de'},
#  'unige.ch': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Geneva',
#   'id': 'unige.ch',
#   'country': 'Switzerland',
#   'alphaTwoCode': 'CH',
#   'webPages': ['http://www.unige.ch/']},
#  'ism.ac.jp': {'parent': 'ac.jp',
#   'shortname': '',
#   'fullname': 'The Institute of Statistical Mathematics, Japan',
#   'id': 'ism.ac.jp'},
#  'spoclab.com': {'country': 'spoclab.com', 'institution': 'spoclab.com'},
#  'upf.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Universitat Pompeu Fabra',
#   'id': 'upf.edu',
#   'country': 'Spain',
#   'alphaTwoCode': 'ES',
#   'webPages': ['http://www.upf.es/', 'https://www.upf.edu/']},
#  'dyns.ucsb.edu': {'country': 'dyns.ucsb.edu', 'institution': 'dyns.ucsb.edu'},
#  'lamda.nju.edu.cn': {'country': 'lamda.nju.edu.cn',
#   'institution': 'lamda.nju.edu.cn'},
#  'seas.upenn.edu': {'parent': 'upenn.edu',
#   'shortname': 'SEAS',
#   'fullname': 'University of Pennsylvania',
#   'id': 'seas.upenn.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.upenn.edu/']},
#  'cit-ec.uni-bielefeld.de': {'country': 'cit-ec.uni-bielefeld.de',
#   'institution': 'cit-ec.uni-bielefeld.de'},
#  'unige.it': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Genoa',
#   'id': 'unige.it',
#   'country': 'Italy',
#   'alphaTwoCode': 'IT',
#   'webPages': ['http://www.unige.it/']},
#  'ryerson.ca': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ryerson Polytechnic University',
#   'id': 'ryerson.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.ryerson.ca/']},
#  'unm.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of New Mexico',
#   'id': 'unm.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.unm.edu/']},
#  'cs.utoronto.ca': {'country': 'cs.utoronto.ca',
#   'institution': 'cs.utoronto.ca'},
#  'cs.put.poznan.pl': {'country': 'cs.put.poznan.pl',
#   'institution': 'cs.put.poznan.pl'},
#  'ehu.eus': {'parent': '',
#   'shortname': '',
#   'fullname': 'Universidad del País Vasco',
#   'id': 'ehu.eus',
#   'country': 'Spain',
#   'alphaTwoCode': 'ES',
#   'webPages': ['http://www.ehu.es/']},
#  'icsi.berkeley.edu': {'country': 'icsi.berkeley.edu',
#   'institution': 'icsi.berkeley.edu'},
#  'monash.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Monash University',
#   'id': 'monash.edu',
#   'country': 'Australia',
#   'alphaTwoCode': 'AU',
#   'webPages': ['http://www.monash.edu/']},
#  'edu.cut.ac.cy': {'country': 'edu.cut.ac.cy', 'institution': 'edu.cut.ac.cy'},
#  'tut.fi': {'parent': '',
#   'shortname': '',
#   'fullname': 'Tampere University of Technology',
#   'id': 'tut.fi',
#   'country': 'Finland',
#   'alphaTwoCode': 'FI',
#   'webPages': ['http://www.tut.fi/']},
#  'jku.at': {'parent': '',
#   'shortname': '',
#   'fullname': 'Johannes Kepler Universität Linz',
#   'id': 'jku.at',
#   'country': 'Austria',
#   'alphaTwoCode': 'AT',
#   'webPages': ['https://www.jku.at/']},
#  'ibm.com': {'parent': None,
#   'shortname': 'IBM',
#   'fullname': 'International Business Machines',
#   'id': 'ibm.com'},
#  'upwork.com': {'country': 'upwork.com', 'institution': 'upwork.com'},
#  'ens.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ecole Normale Supérieure de Paris',
#   'id': 'ens.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['http://www.ens.fr/']},
#  'drexel.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Drexel University',
#   'id': 'drexel.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.drexel.edu/']},
#  'ieor.columbia.edu': {'country': 'ieor.columbia.edu',
#   'institution': 'ieor.columbia.edu'},
#  'enlitic.com': {'country': 'enlitic.com', 'institution': 'enlitic.com'},
#  'idiap.ch': {'parent': None,
#   'shortname': '',
#   'fullname': 'Idiap Research Institute',
#   'id': 'idiap.ch'},
#  'ruc.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Renmin University of China',
#   'id': 'ruc.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.ruc.edu.cn/']},
#  'fias.uni-frankfurt.de': {'parent': 'uni-frankfurt.de',
#   'shortname': '',
#   'fullname': '',
#   'id': 'fias.uni-frankfurt.de'},
#  'lateral.io': {'country': 'lateral.io', 'institution': 'lateral.io'},
#  'iu.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Indiana University',
#   'id': 'iu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.iu.edu/']},
#  'math.pku.edu.cn': {'parent': 'pku.edu.cn',
#   'shortname': '',
#   'fullname': 'School of mathematical Science, Peking University',
#   'id': 'math.pku.edu.cn'},
#  'stat.ucla.edu': {'parent': 'ucla.edu',
#   'shortname': '',
#   'fullname': 'UCLA',
#   'id': 'stat.ucla.edu'},
#  'wolfson.ox.ac.uk': {'country': 'wolfson.ox.ac.uk',
#   'institution': 'wolfson.ox.ac.uk'},
#  'uestc.std.edu.cn': {'country': 'uestc.std.edu.cn',
#   'institution': 'uestc.std.edu.cn'},
#  'umd.edu': {'parent': '',
#   'shortname': 'UMD',
#   'fullname': 'University of Maryland, College Park',
#   'id': 'umd.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.umd.edu/']},
#  'student.uml.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Massachusetts at Lowell',
#   'id': 'student.uml.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.uml.edu/']},
#  'buffalo.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'State University of New York at Buffalo',
#   'id': 'buffalo.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.buffalo.edu/']},
#  'cut.ac.cy': {'parent': '',
#   'shortname': '',
#   'fullname': 'Cyprus University of Technology',
#   'id': 'cut.ac.cy',
#   'country': 'Cyprus',
#   'alphaTwoCode': 'CY',
#   'webPages': ['http://www.cut.ac.cy/']},
#  'baylor.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'Baylor University',
#   'id': 'baylor.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.baylor.edu/']},
#  'roysonlee.com': {'country': 'roysonlee.com', 'institution': 'roysonlee.com'},
#  'gtri.gatech.edu': {'country': 'gtri.gatech.edu',
#   'institution': 'gtri.gatech.edu'},
#  'ucr.edu': {'parent': '',
#   'shortname': 'UCR',
#   'fullname': 'University of California, Riverside',
#   'id': 'ucr.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ucr.edu/']},
#  'student.uva.nl': {'country': 'student.uva.nl',
#   'institution': 'student.uva.nl'},
#  'iis.sinica.edu.tw': {'parent': 'sinica.edu.tw',
#   'shortname': '',
#   'fullname': '',
#   'id': 'iis.sinica.edu.tw'},
#  'cs.ubc.ca': {'parent': 'ubc.ca',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.ubc.ca'},
#  'hdu.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Hangzhou Dianzi University',
#   'id': 'hdu.edu.cn'},
#  'centrale-marseille.fr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Ecole Centrale de Marseille',
#   'id': 'centrale-marseille.fr',
#   'country': 'France',
#   'alphaTwoCode': 'FR',
#   'webPages': ['https://www.centrale-marseille.fr/']},
#  'a9.com': {'parent': None, 'shortname': '', 'fullname': 'A9', 'id': 'a9.com'},
#  'lamsade.dauphine.fr': {'parent': 'dauphine.fr',
#   'shortname': '',
#   'fullname': '',
#   'id': 'lamsade.dauphine.fr'},
#  'cse.iitb.ac.in': {'parent': 'iitb.ac.in',
#   'shortname': '',
#   'fullname': 'Indian Institute of Technology Bombay',
#   'id': 'cse.iitb.ac.in'},
#  'deeplab.ai': {'parent': None,
#   'shortname': '',
#   'fullname': 'DeepLab',
#   'id': 'deeplab.ai'},
#  'tue.mpg.de': {'parent': 'mpg.de',
#   'shortname': '',
#   'fullname': 'Max Planck Institute for Intelligent Systems',
#   'id': 'tue.mpg.de'},
#  'tsc.uc3m.es': {'parent': 'uc3m.es',
#   'shortname': '',
#   'fullname': 'Universidad Carlos III',
#   'id': 'tsc.uc3m.es'},
#  'ic.unicamp.br': {'country': 'ic.unicamp.br', 'institution': 'ic.unicamp.br'},
#  'nt.upb.de': {'country': 'nt.upb.de', 'institution': 'nt.upb.de'},
#  'korea.ac.kr': {'parent': '',
#   'shortname': '',
#   'fullname': 'Korea University',
#   'id': 'korea.ac.kr',
#   'country': 'Korea, Republic of',
#   'alphaTwoCode': 'KR',
#   'webPages': ['http://www.korea.ac.kr/']},
#  'asapp.com': {'parent': None,
#   'shortname': '',
#   'fullname': '',
#   'id': 'asapp.com'},
#  'my.bristol.ac.uk': {'country': 'my.bristol.ac.uk',
#   'institution': 'my.bristol.ac.uk'},
#  'nyu.edu': {'parent': '',
#   'shortname': 'NYU',
#   'fullname': 'New York University',
#   'id': 'nyu.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.nyu.edu/']},
#  'ics.uci.edu': {'parent': 'uci.edu',
#   'shortname': 'ICS',
#   'fullname': 'Donald Bren School of Information and Computer Sciences',
#   'id': 'ics.uci.edu'},
#  'adelaide.edu.au': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Adelaide',
#   'id': 'adelaide.edu.au',
#   'country': 'Australia',
#   'alphaTwoCode': 'AU',
#   'webPages': ['http://www.adelaide.edu.au/']},
#  'mohakshah.com': {'country': 'mohakshah.com', 'institution': 'mohakshah.com'},
#  'math.princeton.edu': {'country': 'math.princeton.edu',
#   'institution': 'math.princeton.edu'},
#  'fb.com': {'parent': None,
#   'shortname': 'Facebook',
#   'fullname': 'Facebook',
#   'id': 'fb.com'},
#  'umbc.edu': {'parent': '',
#   'shortname': 'UMBC',
#   'fullname': 'University of Maryland, Baltimore County',
#   'id': 'umbc.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.umbc.edu/']},
#  'hfut.edu.cn': {'parent': '',
#   'shortname': '',
#   'fullname': 'Hefei University of Technology',
#   'id': 'hfut.edu.cn',
#   'country': 'China',
#   'alphaTwoCode': 'CN',
#   'webPages': ['http://www.hfut.edu.cn/']},
#  'coe.berkeley.edu': {'country': 'coe.berkeley.edu',
#   'institution': 'coe.berkeley.edu'},
#  'megvii.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Megvii Technology Inc.',
#   'id': 'megvii.com'},
#  'cs.ucdavis.edu': {'parent': 'ucdavis.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.ucdavis.edu'},
#  'ualr.edu': {'parent': '',
#   'shortname': '',
#   'fullname': 'University of Arkansas - Little Rock',
#   'id': 'ualr.edu',
#   'country': 'United States',
#   'alphaTwoCode': 'US',
#   'webPages': ['http://www.ualr.edu/']},
#  'cs.stanford.edu': {'parent': 'stanford.edu',
#   'shortname': 'Computer Science',
#   'fullname': 'Computer Science Department',
#   'id': 'cs.stanford.edu'},
#  'naverlabs.com': {'parent': None,
#   'shortname': '',
#   'fullname': 'Naver Labs Europe',
#   'id': 'naverlabs.com'},
#  'um.edu.mo': {'country': 'um.edu.mo', 'institution': 'um.edu.mo'},
#  'bsse.ethz.ch': {'country': 'bsse.ethz.ch', 'institution': 'bsse.ethz.ch'},
#  'hal.t.u-tokyo.ac.jp': {'country': 'hal.t.u-tokyo.ac.jp',
#   'institution': 'hal.t.u-tokyo.ac.jp'},
#  'cs.purdue.edu': {'parent': 'purdue.edu',
#   'shortname': '',
#   'fullname': '',
#   'id': 'cs.purdue.edu'},
#  'umontreal.ca': {'parent': '',
#   'shortname': 'Montreal',
#   'fullname': 'Université de Montréal',
#   'id': 'umontreal.ca',
#   'country': 'Canada',
#   'alphaTwoCode': 'CA',
#   'webPages': ['http://www.umontreal.ca/']},
#  ...}

# %%
institution_dic['ohio.edu']['country']
# Out:
# 'United States'

# %%
#wrapper_get_institution('Naveen.Ramakrishnan@us.bosch.com')

def get_institution_info(row):
    text = row['email']
    domain = text.split('@')[1]
    try:
        output = institution_dic[domain]
        return output['country'],output['fullname']
    except:
        try:
            message = None#'institution_dic error'
            country = email2institution_country(domain,enable_warning=False)
            return country,domain
        except:
            message = None #'email2institution_country error'
            return message,domain

def get_history(row):
    #errored still
    str_2017_position =''
    str_2018_position =''
    str_2019_position =''
    row = row['history']
    try:
        if type(row)==str:
            row = ast.literal_eval(row)

        for dict_history in row:
            #ICLR 2017 submission deadline 11/4/2016
            #ICLR 2018 submission deadline 10/27/2017
            #ICLR 2019 submission deadline 9/27/2018

            start = pd.to_datetime(dict_history['start'],format='%Y')
            if dict_history['end'] is None:
                end = pd.Timestamp.now()
            else:
                end = pd.to_datetime(dict_history['end'],format='%Y')


            if start < pd.to_datetime('11/4/2016') <= end:
                str_2017_position = dict_history['position']

            if start < pd.to_datetime('10/27/2017') <= end:
                str_2018_position = dict_history['position']

            if start < pd.to_datetime('9/27/2018') <= end:
                str_2019_position = dict_history['position']            

        return str_2017_position, str_2018_position, str_2019_position
    except:
        return None,None,None

# %%
ast.literal_eval(df_author_info.history[7])
# Out:
# []

# %%
#get the institutional location through automatic tool
tqdm.tqdm.pandas()
update = 1
if update == 1:
    df_author_info[['location','institution']]=df_author_info.progress_apply(lambda x: get_institution_info(x),axis=1,result_type = 'expand')
    df_author_info.to_csv('./data/authors/df_author_profiles.csv',index=False)
else:
    pass
# Out:
# 100%|███████████████████████████████████████| 8106/8106 [03:19<00:00, 40.65it/s]

# %%
tqdm.tqdm.pandas()
update = 1
if update == 1:
    df_author_info[['2017_position','2018_position','2019_position']]=df_author_info.progress_apply(lambda x: get_history(x),axis=1,result_type = 'expand')
    df_author_info.to_csv('./data/authors/df_author_profiles.csv',index=False)
else:
    pass
# Out:
# 100%|█████████████████████████████████████| 8106/8106 [00:06<00:00, 1244.97it/s]

# %%
df_author_info[['2017_position','2018_position','2019_position']]
# Out:
#             2017_position        2018_position        2019_position
# 0                    None                 None                 None
# 1
# 2                    None                 None                 None
# 3                    None                 None                 None
# 4                    None                 None                 None
# ...                   ...                  ...                  ...
# 8101                 None                 None                 None
# 8102                 None                 None                 None
# 8103          PhD student          PhD student          PhD student
# 8104  Associate Professor  Associate Professor  Associate Professor
# 8105  Assistant Professor  Assistant Professor
#
# [8106 rows x 3 columns]

# %%
df_author_info['location'].value_counts().nlargest(20).plot(kind='bar',figsize = (4,2))
# Out:
# <AxesSubplot:>

# %%
df_author_loaction_2017 = df_author_info.query("year==2017")
df_author_loaction_2018 = df_author_info.query("year==2018")
df_author_loaction_2019 = df_author_info.query("year==2019")


x1 = df_author_loaction_2017['location'].value_counts().nlargest(20).plot(kind='bar',figsize = (4,2))

# %%
df_author_loaction_2018['location'].value_counts().nlargest(20).plot(kind='bar',figsize = (4,2))
# Out:
# <AxesSubplot:>

# %%
df_author_loaction_2019['location'].value_counts().nlargest(20).plot(kind='bar',figsize = (4,2))
# Out:
# <AxesSubplot:>

# %%
df_author_loaction_2019['institution'].value_counts().nlargest(20).plot(kind='bar',figsize = (4,2))
# Out:
# <AxesSubplot:>

# %%
df_author_info.groupby('institution')['institution'].count().nlargest(50)
# Out:
# institution
# gmail.com                                           966
# google.com                                          810
# microsoft.com                                       182
# University of California, Berkeley                  161
# Massachusetts Institute of Technology               158
# cs.cmu.edu                                          136
# fb.com                                              126
# Stanford University                                 122
# us.ibm.com                                           96
# Peking University                                    91
# cs.stanford.edu                                      80
# University of Michigan - Ann Arbor                   75
# cs.toronto.edu                                       74
# University of Illinois at Urbana-Champaign           70
# Georgia Institute of Technology                      69
# intel.com                                            60
# Korea Advanced Institute of Science & Technology     57
# University of Southern California                    57
# eecs.berkeley.edu                                    56
# Duke University                                      49
# andrew.cmu.edu                                       47
# baidu.com                                            46
# cs.washington.edu                                    46
# Université de Montréal                               43
# University of Cambridge                              42
# inf.ethz.ch                                          42
# New York University                                  41
# Columbia University                                  40
# Imperial College London                              40
# Seoul National University                            40
# robots.ox.ac.uk                                      40
# csail.mit.edu                                        37
# Cornell University                                   36
# EPFL - EPF Lausanne                                  35
# nvidia.com                                           34
# ibm.com                                              31
# mails.tsinghua.edu.cn                                31
# openai.com                                           30
# inria.fr                                             28
# ttic.edu                                             28
# University of Edinburgh                              27
# cs.umass.edu                                         27
# Princeton University                                 26
# University of Amsterdam                              26
# University of California, San Diego                  26
# University of Texas at Austin                        26
# University of Washington                             26
# Carnegie Mellon University                           25
# Rice University                                      24
# University of Pennsylvania                           24
# Name: institution, dtype: int64

# %%
df_author_info.groupby(['location']).institution.count()
# Out:
# location
# Anguilla                            42
# Australia                           75
# Austria                             38
# Belgium                             20
# Brazil                              25
# British Indian Ocean Territory      13
# Canada                             377
# Chile                                2
# China                              511
# Cocos (Keeling) Islands              4
# Colombia                             2
# Croatia                              4
# Cyprus                               2
# Czechia                              7
# Denmark                             11
# Egypt                                3
# European Union                       5
# Finland                             10
# France                             174
# Germany                            241
# Greece                               5
# Hong Kong                           41
# India                               54
# Iran                                 3
# Ireland                              3
# Israel                              75
# Italy                               35
# Japan                              153
# Korea, Republic of                 130
# Macao                                1
# Mexico                               3
# Montenegro                           2
# Netherlands                         42
# New Zealand                          8
# Platform                          1014
# Poland                              21
# Portugal                            12
# Qatar                                3
# Russian Federation                  22
# Sao Tome and Principe                1
# Saudi Arabia                         7
# Singapore                           56
# South Korea                         71
# Soviet Union                         1
# Spain                               32
# Sweden                              16
# Switzerland                        172
# Taiwan                              31
# Turkey                               5
# United Arab Emirates                 1
# United Kingdom                     357
# United States                     4159
# Uruguay                              2
# Vietnam                              1
# Name: institution, dtype: int64

# %%
df_missing_locations_by_domiain = pd.read_csv('./data/authors/email_location_missing.csv')

dict_missing_email_location = {}
for index, row in df_missing_locations_by_domiain.iterrows():
    dict_missing_email_location[row[0]] = row[1]

# %%
def get_missing_location(row):
    try:
        location = dict_missing_email_location[row['institution']]
    except:
        location = row['location']
    return location

df_author_info['location'] = df_author_info.apply(lambda x: get_missing_location(x), axis = 1)

# %%
df_author_info.to_csv('./data/authors/df_author_profiles.csv',index=False)
